# %% [markdown]
# # Initial Data Exploration

# %% [markdown]
# ## Imports and configuration

# %%
import os, glob, re, xml.etree.ElementTree as ET
import json
from pathlib import Path

from itertools import combinations
from collections import defaultdict

import seaborn as sns
import matplotlib.pyplot as plt

import re

import numpy as np
import pandas as pd
from scipy.sparse import csr_matrix

# ── Dynamic path configuration ────────────────────────────────────────────────
project_root = Path.cwd()
default_data_dir = project_root / "data"

env_data_dir = os.getenv("DATA_DIR")
local_cfg_path = project_root / "paths.local.json"

if env_data_dir:
    data_dir = Path(env_data_dir).expanduser()
elif local_cfg_path.exists():
    data_dir = Path(json.loads(local_cfg_path.read_text())["data_dir"]).expanduser()
else:
    data_dir = default_data_dir

CORPUS_DIR = data_dir / "corpus"
GT_PATH    = data_dir / "ground_truth.tsv"

np.random.seed(42)
print("Imports OK")

debug = False # flag for indicating we're using the alt dataset
print(f"Running in debug mode: {debug}")
# Out:
# Imports OK
# Running in debug mode: False

# %%
# import zipfile
# from pathlib import Path
# import os

# ZIP_PATH = Path('/content/15_Suspicious_Passages.zip')
# EXTRACT_DIR = Path('/content/extracted_suspicious_data')

# os.makedirs(EXTRACT_DIR, exist_ok=True)

# with zipfile.ZipFile(ZIP_PATH, 'r') as zip_ref:
#     zip_ref.extractall(EXTRACT_DIR)

# print("Extraction complete.")
# Out:
# Extraction complete.

# %%
# Use dynamic path configuration from the setup cell above.
# Keep GROUND_TRUTH_PATH for compatibility with downstream cells.
DATASET_DIR = CORPUS_DIR.parent
GROUND_TRUTH_PATH = GT_PATH

print(f"Using data directory: {data_dir}")
print(f"Using dataset directory: {DATASET_DIR}")
print(f"Using corpus directory: {CORPUS_DIR}")
print(f"Using ground truth file: {GROUND_TRUTH_PATH}")
print("Corpus exists:", CORPUS_DIR.exists())
print("Ground truth exists:", GROUND_TRUTH_PATH.exists())

if not CORPUS_DIR.exists() or not GROUND_TRUTH_PATH.exists():
    raise FileNotFoundError(
        "Dataset paths are invalid. Set DATA_DIR, update paths.local.json, or place files under ./data/."
    )
# Out:
# Using data directory: /Users/vitto/Desktop/SP26/DA/project_1/15_Suspicious_Passages/31.Suspicious_Passages
# Using dataset directory: /Users/vitto/Desktop/SP26/DA/project_1/15_Suspicious_Passages/31.Suspicious_Passages
# Using corpus directory: /Users/vitto/Desktop/SP26/DA/project_1/15_Suspicious_Passages/31.Suspicious_Passages/corpus
# Using ground truth file: /Users/vitto/Desktop/SP26/DA/project_1/15_Suspicious_Passages/31.Suspicious_Passages/ground_truth.tsv
# Corpus exists: True
# Ground truth exists: True

# %%
labels_df = pd.read_csv(GROUND_TRUTH_PATH, sep='\t')
print(labels_df.head())
print(labels_df.columns.tolist())
print(labels_df.shape)
# Out:
#         doc_name  plagiarism
# 0  document01421           1
# 1  document00852           0
# 2  document02154           1
# 3  document05907           1
# 4  document06948           1
# ['doc_name', 'plagiarism']
# (902, 2)

# %%
def read_text_file(path):
    try:
        return path.read_text(encoding='utf-8')
    except:
        return path.read_text(errors='ignore')

source_map = {}

for p in CORPUS_DIR.iterdir():
    if p.name.startswith("source-") and p.suffix == ".txt":
        key = p.stem.replace("source-", "")
        source_map[key] = read_text_file(p)

# %%
labels_df['text'] = labels_df['doc_name'].map(source_map)

missing_count = labels_df['text'].isna().sum()
print(f"Missing text values identified: {missing_count}")

labels_df['text'] = labels_df['text'].fillna('')
labels_df['plagiarism'] = labels_df['plagiarism'].fillna(0).astype(int)

labels_df['char_length'] = labels_df['text'].apply(len)
labels_df['word_count'] = labels_df['text'].apply(lambda x: len(x.split()))

print(labels_df[['doc_name', 'word_count']].head())
print("Empty rows:", (labels_df['text'] == '').sum())
# Out:
# Missing text values identified: 0
#         doc_name  word_count
# 0  document01421       67469
# 1  document00852        1404
# 2  document02154        4100
# 3  document05907        2464
# 4  document06948       29560
# Empty rows: 0

# %%
summary = {
    'documents': len(labels_df),
    'plagiarized_docs': int(labels_df['plagiarism'].sum()),
    'non_plagiarized_docs': int((1 - labels_df['plagiarism']).sum()),
    'avg_word_count': float(round(labels_df['word_count'].mean(), 2)),
    'median_word_count': round(labels_df['word_count'].median(), 2),
    'min_word_count': int(labels_df['word_count'].min()),
    'max_word_count': int(labels_df['word_count'].max()),
}
summary
# Out:
# {'documents': 902,
#  'plagiarized_docs': 451,
#  'non_plagiarized_docs': 451,
#  'avg_word_count': 29053.64,
#  'median_word_count': np.float64(5564.5),
#  'min_word_count': 137,
#  'max_word_count': 434472}

# %%
plt.figure(figsize=(8,5))
plt.hist(labels_df['word_count'], bins=30)
plt.xlabel('Word count')
plt.ylabel('Number of documents')
plt.title('Distribution of document lengths')
plt.show()

# %%
labels_df['plagiarism'].value_counts()
# Out:
# plagiarism
# 1    451
# 0    451
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,4))
labels_df['plagiarism'].value_counts().sort_index().plot(kind='bar')
plt.xticks([0, 1], ['Non-plagiarized', 'Plagiarized'], rotation=0)
plt.ylabel('Count')
plt.title('Class distribution')
plt.show()

# %%
def get_obfuscation_type(doc_name):
    """Extracts the type of plagiarism manipulation from the XML metadata."""
    xml_path = CORPUS_DIR / f"suspicious-{doc_name}.xml"
    if not xml_path.exists():
        return 'none'

    tree = ET.parse(xml_path)
    root = tree.getroot()
    features = root.findall(".//feature[@name='artificial-plagiarism']")

    if features:
        return features[0].get('obfuscation', 'none')
    return 'none'

labels_df['disguise'] = labels_df['doc_name'].apply(get_obfuscation_type)

plt.figure(figsize=(8, 5))
sns.countplot(data=labels_df[labels_df['plagiarism'] == 1], x='disguise')

plt.title('Types of Disguise Used in Plagiarized Documents')
plt.xlabel('Disguise Technique')
plt.ylabel('Number of Documents')
plt.show()

# %%
def preprocess(text):
    text = str(text).lower()
    text = re.sub(r'[^a-zA-Z\s]', ' ', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

labels_df['clean_text'] = labels_df['text'].apply(preprocess)
labels_df[['doc_name', 'clean_text']].head()
# Out:
#         doc_name                                         clean_text
# 0  document01421  produced by stan goodman ted garvin c markus a...
# 1  document00852  whether you enjoy the house in marylebone duck...
# 2  document02154  they were seated on the sofa the black broadcl...
# 3  document05907  it was at rome on the th of october as i sat m...
# 4  document06948  this ebook was produced by eric eldred the sev...

# %% [markdown]
# # Locality-Sensitive Hashing (LSH)
# The following code is based on the `testing_lsh` notebook we saw during the 3rd tutorial. It has been expanded and adapted to suit the needs of the project.

# %%
# ── Load dataset (debug mode) ───────────────────────────────────────────────
# This loads the 20 newsgroups dataset, which is much smaller than the PAN plagiarism corpus, and allows us to compare our results against a known baseline.
# The reference results are found in: https://github.com/MikaBattineni/Plagiarism-Detection-LSH
if debug:
    from sklearn.datasets import fetch_20newsgroups
    import time

    dataset = fetch_20newsgroups(
        subset='all',
        categories=['comp.graphics', 'sci.med', 'talk.politics.mideast'],
        remove=('headers', 'footers', 'quotes')
    )

    start_time = time.time()

    documents = dataset.data
    print(f"Loaded {len(documents)} documents in {time.time()-start_time:.2f}s")

# %% [markdown]
# ## 2. Load Ground Truth

# %%
gt = pd.read_csv(GT_PATH, sep="\t")
gt.columns = gt.columns.str.strip()

# sort by doc_name to match the order of files in CORPUS_DIR
gt = gt.sort_values("doc_name").reset_index(drop=True)

# remove duplicate doc_name entries if any (keep the first occurrence)
gt = gt.drop_duplicates(subset="doc_name", keep="first").reset_index(drop=True)

# crop doc name to just the the ID after "document" (e.g., "0001" from "suspicious-document0001")
gt["doc_name"] = gt["doc_name"].str.extract(r"document(\d+)")

print(f"Ground truth shape: {gt.shape}")
gt.head(10)
# Out:
# Ground truth shape: (902, 2)
#   doc_name  plagiarism
# 0    00014           1
# 1    00044           1
# 2    00052           0
# 3    00060           0
# 4    00072           0
# 5    00083           1
# 6    00085           1
# 7    00087           0
# 8    00088           1
# 9    00093           1

# %%
print(gt["plagiarism"].value_counts().rename({1: "Plagiarised", 0: "Clean"}))
# Out:
# plagiarism
# Plagiarised    451
# Clean          451
# Name: count, dtype: int64

# %% [markdown]
# ## 3. Parse XML Metadata

# %%
def parse_xml_meta(xml_path: Path) -> dict:
    """Return a dict with doc_name, is_plagiarised, and a list of plagiarism features.
    
    The XML reference attribute points to the companion .txt file, e.g.:
        reference="suspicious-document05744.txt"
    Doc names are normalised to the stem without extension.
    """
    tree = ET.parse(xml_path)
    root = tree.getroot()
    doc_ref  = root.get("reference", xml_path.stem + ".txt")
    doc_name = Path(doc_ref).stem   # e.g. "suspicious-document05744"

    features = []
    for feat in root.findall("feature"):
        if feat.get("name") == "artificial-plagiarism":
            features.append({
                "obfuscation"  : feat.get("obfuscation", "none"),
                "this_offset"  : int(feat.get("this_offset", 0)),
                "this_length"  : int(feat.get("this_length", 0)),
                "source_ref"   : feat.get("source_reference", ""),
                "source_offset": int(feat.get("source_offset", 0)),
                "source_length": int(feat.get("source_length", 0)),
            })

    return {"doc_name": doc_name, "is_plagiarised": len(features) > 0, "features": features}

# All XML files are in the single corpus directory
xml_files = sorted(CORPUS_DIR.glob("suspicious-document*.xml"))
print(f"Found {len(xml_files)} XML metadata files")

meta_records = [parse_xml_meta(p) for p in xml_files]
meta_df = pd.DataFrame([{k: v for k, v in r.items() if k != "features"} for r in meta_records])
# change is_plagiarised to match the GT labels (1 for plagiarised, 0 for clean)
meta_df["is_plagiarised"] = meta_df["is_plagiarised"].astype(int)
# crop doc name to just the the ID after "document" (e.g., "0001" from "suspicious-document0001")
meta_df["doc_name"] = meta_df["doc_name"].str.extract(r"document(\d+)")

print(meta_df["is_plagiarised"].value_counts().rename({True: "Plagiarised", False: "Clean"}))
meta_df.head()
# Out:
# Found 901 XML metadata files
# is_plagiarised
# Clean          451
# Plagiarised    450
# Name: count, dtype: int64
#   doc_name  is_plagiarised
# 0    00014               1
# 1    00044               1
# 2    00052               0
# 3    00060               0
# 4    00072               0

# %% [markdown]
# # 4. Sanity Check

# %%
# Find plagiarised documents present in ground truth but missing from the XML metadata
gt_plag = set(gt.loc[gt["plagiarism"] == 1, "doc_name"])
meta_plag = set(
    meta_df.loc[meta_df["is_plagiarised"] == 1, "doc_name"].str.replace("suspicious-", "", regex=False)
)

missing_from_xml = sorted(gt_plag - meta_plag)
extra_in_xml = sorted(meta_plag - gt_plag)

print(f"Plagiarised docs in GT   : {len(gt_plag)}")
print(f"Plagiarised docs in XML  : {len(meta_plag)}")
print(f"Missing from XML metadata: {len(missing_from_xml)}")
print(f"Extra in XML metadata    : {len(extra_in_xml)}")

if missing_from_xml:
    print("\nMissing document(s):")
    for doc in missing_from_xml:
        print(doc, "-> expected XML:", CORPUS_DIR / f"suspicious-{doc}.xml")

        # drop the missing doc from GT to keep the dataset consistent
        gt = gt[gt["doc_name"] != doc]
        print(f"Dropped {doc} from GT, new GT shape: {gt.shape}")
# Out:
# Plagiarised docs in GT   : 451
# Plagiarised docs in XML  : 450
# Missing from XML metadata: 1
# Extra in XML metadata    : 0
#
# Missing document(s):
# 06862 -> expected XML: /Users/vitto/Desktop/SP26/DA/project_1/15_Suspicious_Passages/31.Suspicious_Passages/corpus/suspicious-06862.xml
# Dropped 06862 from GT, new GT shape: (901, 2)

# %%
def build_plagiarism_map(xml_dir):
    """
    Build a mapping of document IDs to their plagiarized sources.
    
    Args:
        xml_dir: Path to directory containing suspicious-document*.xml files
        
    Returns:
        Dict[str, List[str]]: Maps document IDs to list of source document IDs they plagiarized from.
                              Documents with 0 plagiarism are not included in the map.
    """
    plagiarism_map = defaultdict(list)
    
    # Get all XML files for suspicious documents
    xml_files = sorted(xml_dir.glob("suspicious-document*.xml"))
    
    for xml_file in xml_files:
        # Extract document ID from filename (e.g., "suspicious-document00925.xml" -> "00925")
        doc_id = xml_file.stem.replace("suspicious-document", "")
        
        try:
            tree = ET.parse(xml_file)
            root = tree.getroot()
            
            # Find all artificial-plagiarism features
            for feature in root.findall(".//feature[@name='artificial-plagiarism']"):
                source_ref = feature.get("source_reference")
                if source_ref:
                    # Extract source document ID from reference
                    # e.g., "source-document02721.txt" -> "02721"
                    source_id = source_ref.replace("source-document", "").replace(".txt", "")
                    plagiarism_map[doc_id].append(source_id)
        except ET.ParseError as e:
            print(f"Error parsing {xml_file}: {e}")
    
    return dict(plagiarism_map)

# Build the plagiarism map
plagiarism_map = build_plagiarism_map(CORPUS_DIR)

# %%
# Print summary statistics
total_plagiarized = len(plagiarism_map)
total_docs_in_corpus = len(list(CORPUS_DIR.glob("suspicious-document*.xml")))
total_sources = sum(len(sources) for sources in plagiarism_map.values())

print(f"Total documents in corpus: {total_docs_in_corpus}")
print(f"Documents with plagiarism: {total_plagiarized}")
print(f"Total plagiarism instances: {total_sources}")
print(f"\nExample entries:")
for i, (doc_id, sources) in enumerate(list(plagiarism_map.items())[:5]):
    print(f"  Document {doc_id}: plagiarized from {sources}")
# Out:
# Total documents in corpus: 901
# Documents with plagiarism: 450
# Total plagiarism instances: 4676
#
# Example entries:
#   Document 00014: plagiarized from ['03390', '05760', '04633', '05507', '02701', '00852', '03686', '04633', '04678', '03390', '05822', '06355', '04633', '03686', '03686', '02701', '04633', '03686', '03686', '03686', '03686', '03686', '04633', '05822', '00912']
#   Document 00044: plagiarized from ['05976', '05976', '05976', '05976', '05976', '05976']
#   Document 00083: plagiarized from ['04661', '04886', '03574', '04886', '04886', '05659', '03574', '02104', '03574', '04023', '03574', '01167', '03574', '03574', '03574', '03574', '04661', '04886', '03574', '01167', '02104']
#   Document 00085: plagiarized from ['05039', '05039', '05039']
#   Document 00088: plagiarized from ['07074', '05235', '07074', '07074', '05235']

# %%
# sanity check: check that the keys in the plagiarism map match the entries with a 1 in the GT
assert set(gt.loc[gt["plagiarism"] == 1, "doc_name"]) == set(plagiarism_map.keys()), "Mismatch between GT and XML metadata for plagiarised documents"
# # if there is a mismatch, print the offending document ID and the expected XML file path
# for doc_id in gt.loc[gt["plagiarism"] == 1, "doc_name"]:
#     if doc_id not in plagiarism_map:
#         print(f"GT indicates {doc_id} is plagiarised but it's missing from XML metadata.")
#         print(f"Expected XML file: {CORPUS_DIR / f'suspicious-{doc_id}.xml'}")

# %%
# For each document in the plagiarism map:
# 1) remove source IDs whose source-document*.txt is missing
# 2) if no valid sources remain, remove the document from the map

initial_map_size = len(plagiarism_map)
print(f"Initial plagiarism map size: {initial_map_size}")

removed_sources_total = 0

for doc_id, sources in list(plagiarism_map.items()):
    valid_sources = [
        src_id for src_id in sources
        if (CORPUS_DIR / f"source-document{src_id}.txt").exists()
    ]

    removed_count = len(sources) - len(valid_sources)
    if removed_count > 0:
        removed_sources_total += removed_count
        print(f"Document {doc_id}: removed {removed_count} unavailable source(s).")

    if valid_sources:
        plagiarism_map[doc_id] = valid_sources
    else:
        print(f"Document {doc_id} has no available sources. Removing from map.")
        del plagiarism_map[doc_id]

final_map_size = len(plagiarism_map)
print(f"Final plagiarism map size: {final_map_size}")
print(f"Total unavailable sources removed: {removed_sources_total}")
# Out:
# Initial plagiarism map size: 450
# Document 00014: removed 23 unavailable source(s).
# Document 00044: removed 6 unavailable source(s).
# Document 00044 has no available sources. Removing from map.
# Document 00083: removed 21 unavailable source(s).
# Document 00083 has no available sources. Removing from map.
# Document 00085: removed 3 unavailable source(s).
# Document 00085 has no available sources. Removing from map.
# Document 00088: removed 5 unavailable source(s).
# Document 00088 has no available sources. Removing from map.
# Document 00093: removed 3 unavailable source(s).
# Document 00093 has no available sources. Removing from map.
# Document 00108: removed 65 unavailable source(s).
# Document 00108 has no available sources. Removing from map.
# Document 00109: removed 65 unavailable source(s).
# Document 00117: removed 2 unavailable source(s).
# Document 00117 has no available sources. Removing from map.
# Document 00123: removed 4 unavailable source(s).
# Document 00123 has no available sources. Removing from map.
# Document 00146: removed 3 unavailable source(s).
# Document 00146 has no available sources. Removing from map.
# Document 00147: removed 35 unavailable source(s).
# Document 00147 has no available sources. Removing from map.
# Document 00155: removed 19 unavailable source(s).
# Document 00155 has no available sources. Removing from map.
# Document 00171: removed 28 unavailable source(s).
# Document 00216: removed 5 unavailable source(s).
# Document 00216 has no available sources. Removing from map.
# Document 00246: removed 4 unavailable source(s).
# Document 00246 has no available sources. Removing from map.
# Document 00264: removed 8 unavailable source(s).
# Document 00266: removed 3 unavailable source(s).
# Document 00266 has no available sources. Removing from map.
# Document 00268: removed 2 unavailable source(s).
# Document 00268 has no available sources. Removing from map.
# Document 00357: removed 3 unavailable source(s).
# Document 00373: removed 9 unavailable source(s).
# Document 00373 has no available sources. Removing from map.
# Document 00384: removed 5 unavailable source(s).
# Document 00384 has no available sources. Removing from map.
# Document 00390: removed 4 unavailable source(s).
# Document 00390 has no available sources. Removing from map.
# Document 00392: removed 2 unavailable source(s).
# Document 00392 has no available sources. Removing from map.
# Document 00403: removed 6 unavailable source(s).
# Document 00403 has no available sources. Removing from map.
# Document 00411: removed 11 unavailable source(s).
# Document 00411 has no available sources. Removing from map.
# Document 00431: removed 8 unavailable source(s).
# Document 00431 has no available sources. Removing from map.
# Document 00432: removed 6 unavailable source(s).
# Document 00432 has no available sources. Removing from map.
# Document 00445: removed 2 unavailable source(s).
# Document 00446: removed 3 unavailable source(s).
# Document 00446 has no available sources. Removing from map.
# Document 00461: removed 8 unavailable source(s).
# Document 00461 has no available sources. Removing from map.
# Document 00468: removed 22 unavailable source(s).
# Document 00476: removed 4 unavailable source(s).
# Document 00482: removed 4 unavailable source(s).
# Document 00482 has no available sources. Removing from map.
# Document 00503: removed 18 unavailable source(s).
# Document 00503 has no available sources. Removing from map.
# Document 00509: removed 2 unavailable source(s).
# Document 00509 has no available sources. Removing from map.
# Document 00511: removed 6 unavailable source(s).
# Document 00514: removed 15 unavailable source(s).
# Document 00549: removed 3 unavailable source(s).
# Document 00549 has no available sources. Removing from map.
# Document 00552: removed 26 unavailable source(s).
# Document 00577: removed 6 unavailable source(s).
# Document 00577 has no available sources. Removing from map.
# Document 00610: removed 22 unavailable source(s).
# Document 00610 has no available sources. Removing from map.
# Document 00630: removed 10 unavailable source(s).
# Document 00634: removed 10 unavailable source(s).
# Document 00634 has no available sources. Removing from map.
# Document 00643: removed 6 unavailable source(s).
# Document 00643 has no available sources. Removing from map.
# Document 00676: removed 11 unavailable source(s).
# Document 00676 has no available sources. Removing from map.
# Document 00677: removed 5 unavailable source(s).
# Document 00677 has no available sources. Removing from map.
# Document 00682: removed 39 unavailable source(s).
# Document 00735: removed 1 unavailable source(s).
# Document 00760: removed 10 unavailable source(s).
# Document 00768: removed 7 unavailable source(s).
# Document 00768 has no available sources. Removing from map.
# Document 00773: removed 1 unavailable source(s).
# Document 00775: removed 9 unavailable source(s).
# Document 00775 has no available sources. Removing from map.
# Document 00787: removed 1 unavailable source(s).
# Document 00787 has no available sources. Removing from map.
# Document 00800: removed 14 unavailable source(s).
# Document 00800 has no available sources. Removing from map.
# Document 00803: removed 5 unavailable source(s).
# Document 00803 has no available sources. Removing from map.
# Document 00838: removed 22 unavailable source(s).
# Document 00838 has no available sources. Removing from map.
# Document 00842: removed 18 unavailable source(s).
# Document 00864: removed 4 unavailable source(s).
# Document 00864 has no available sources. Removing from map.
# Document 00870: removed 6 unavailable source(s).
# Document 00870 has no available sources. Removing from map.
# Document 00886: removed 6 unavailable source(s).
# Document 00893: removed 1 unavailable source(s).
# Document 00897: removed 23 unavailable source(s).
# Document 00897 has no available sources. Removing from map.
# Document 00917: removed 2 unavailable source(s).
# Document 00917 has no available sources. Removing from map.
# Document 00925: removed 1 unavailable source(s).
# Document 00925 has no available sources. Removing from map.
# Document 00961: removed 25 unavailable source(s).
# Document 00965: removed 10 unavailable source(s).
# Document 00967: removed 10 unavailable source(s).
# Document 00967 has no available sources. Removing from map.
# Document 00970: removed 5 unavailable source(s).
# Document 00970 has no available sources. Removing from map.
# Document 00972: removed 3 unavailable source(s).
# Document 00972 has no available sources. Removing from map.
# Document 00984: removed 12 unavailable source(s).
# Document 00984 has no available sources. Removing from map.
# Document 01018: removed 34 unavailable source(s).
# Document 01018 has no available sources. Removing from map.
# Document 01063: removed 3 unavailable source(s).
# Document 01063 has no available sources. Removing from map.
# Document 01065: removed 7 unavailable source(s).
# Document 01093: removed 7 unavailable source(s).
# Document 01093 has no available sources. Removing from map.
# Document 01096: removed 8 unavailable source(s).
# Document 01128: removed 22 unavailable source(s).
# Document 01141: removed 4 unavailable source(s).
# Document 01160: removed 13 unavailable source(s).
# Document 01160 has no available sources. Removing from map.
# Document 01166: removed 1 unavailable source(s).
# Document 01166 has no available sources. Removing from map.
# Document 01217: removed 2 unavailable source(s).
# Document 01217 has no available sources. Removing from map.
# Document 01227: removed 9 unavailable source(s).
# Document 01227 has no available sources. Removing from map.
# Document 01322: removed 11 unavailable source(s).
# Document 01322 has no available sources. Removing from map.
# Document 01335: removed 3 unavailable source(s).
# Document 01380: removed 2 unavailable source(s).
# Document 01380 has no available sources. Removing from map.
# Document 01399: removed 3 unavailable source(s).
# Document 01399 has no available sources. Removing from map.
# Document 01403: removed 30 unavailable source(s).
# Document 01403 has no available sources. Removing from map.
# Document 01413: removed 16 unavailable source(s).
# Document 01413 has no available sources. Removing from map.
# Document 01421: removed 3 unavailable source(s).
# Document 01421 has no available sources. Removing from map.
# Document 01426: removed 10 unavailable source(s).
# Document 01426 has no available sources. Removing from map.
# Document 01445: removed 2 unavailable source(s).
# Document 01445 has no available sources. Removing from map.
# Document 01457: removed 4 unavailable source(s).
# Document 01457 has no available sources. Removing from map.
# Document 01472: removed 5 unavailable source(s).
# Document 01472 has no available sources. Removing from map.
# Document 01507: removed 6 unavailable source(s).
# Document 01508: removed 2 unavailable source(s).
# Document 01575: removed 28 unavailable source(s).
# Document 01585: removed 8 unavailable source(s).
# Document 01585 has no available sources. Removing from map.
# Document 01630: removed 4 unavailable source(s).
# Document 01630 has no available sources. Removing from map.
# Document 01634: removed 7 unavailable source(s).
# Document 01634 has no available sources. Removing from map.
# Document 01646: removed 3 unavailable source(s).
# Document 01659: removed 5 unavailable source(s).
# Document 01659 has no available sources. Removing from map.
# Document 01675: removed 3 unavailable source(s).
# Document 01675 has no available sources. Removing from map.
# Document 01699: removed 4 unavailable source(s).
# Document 01699 has no available sources. Removing from map.
# Document 01723: removed 20 unavailable source(s).
# Document 01723 has no available sources. Removing from map.
# Document 01739: removed 15 unavailable source(s).
# Document 01751: removed 1 unavailable source(s).
# Document 01751 has no available sources. Removing from map.
# Document 01755: removed 1 unavailable source(s).
# Document 01780: removed 8 unavailable source(s).
# Document 01780 has no available sources. Removing from map.
# Document 01792: removed 4 unavailable source(s).
# Document 01792 has no available sources. Removing from map.
# Document 01807: removed 13 unavailable source(s).
# Document 01815: removed 11 unavailable source(s).
# Document 01815 has no available sources. Removing from map.
# Document 01823: removed 3 unavailable source(s).
# Document 01823 has no available sources. Removing from map.
# Document 01861: removed 6 unavailable source(s).
# Document 01861 has no available sources. Removing from map.
# Document 01869: removed 7 unavailable source(s).
# Document 01869 has no available sources. Removing from map.
# Document 01873: removed 5 unavailable source(s).
# Document 01873 has no available sources. Removing from map.
# Document 01875: removed 8 unavailable source(s).
# Document 01875 has no available sources. Removing from map.
# Document 01906: removed 39 unavailable source(s).
# Document 01925: removed 4 unavailable source(s).
# Document 01935: removed 11 unavailable source(s).
# Document 01937: removed 3 unavailable source(s).
# Document 01954: removed 2 unavailable source(s).
# Document 01954 has no available sources. Removing from map.
# Document 01990: removed 3 unavailable source(s).
# Document 01990 has no available sources. Removing from map.
# Document 01995: removed 5 unavailable source(s).
# Document 01995 has no available sources. Removing from map.
# Document 02034: removed 10 unavailable source(s).
# Document 02034 has no available sources. Removing from map.
# Document 02049: removed 29 unavailable source(s).
# Document 02049 has no available sources. Removing from map.
# Document 02050: removed 4 unavailable source(s).
# Document 02050 has no available sources. Removing from map.
# Document 02062: removed 5 unavailable source(s).
# Document 02062 has no available sources. Removing from map.
# Document 02064: removed 3 unavailable source(s).
# Document 02068: removed 1 unavailable source(s).
# Document 02068 has no available sources. Removing from map.
# Document 02084: removed 6 unavailable source(s).
# Document 02084 has no available sources. Removing from map.
# Document 02129: removed 1 unavailable source(s).
# Document 02129 has no available sources. Removing from map.
# Document 02142: removed 7 unavailable source(s).
# Document 02142 has no available sources. Removing from map.
# Document 02150: removed 1 unavailable source(s).
# Document 02150 has no available sources. Removing from map.
# Document 02154: removed 8 unavailable source(s).
# Document 02154 has no available sources. Removing from map.
# Document 02166: removed 21 unavailable source(s).
# Document 02191: removed 16 unavailable source(s).
# Document 02191 has no available sources. Removing from map.
# Document 02199: removed 4 unavailable source(s).
# Document 02199 has no available sources. Removing from map.
# Document 02203: removed 3 unavailable source(s).
# Document 02203 has no available sources. Removing from map.
# Document 02239: removed 15 unavailable source(s).
# Document 02239 has no available sources. Removing from map.
# Document 02260: removed 2 unavailable source(s).
# Document 02275: removed 10 unavailable source(s).
# Document 02296: removed 2 unavailable source(s).
# Document 02296 has no available sources. Removing from map.
# Document 02299: removed 3 unavailable source(s).
# Document 02299 has no available sources. Removing from map.
# Document 02316: removed 5 unavailable source(s).
# Document 02347: removed 3 unavailable source(s).
# Document 02347 has no available sources. Removing from map.
# Document 02366: removed 7 unavailable source(s).
# Document 02366 has no available sources. Removing from map.
# Document 02393: removed 7 unavailable source(s).
# Document 02393 has no available sources. Removing from map.
# Document 02399: removed 4 unavailable source(s).
# Document 02399 has no available sources. Removing from map.
# Document 02415: removed 14 unavailable source(s).
# Document 02415 has no available sources. Removing from map.
# Document 02418: removed 1 unavailable source(s).
# Document 02418 has no available sources. Removing from map.
# Document 02427: removed 21 unavailable source(s).
# Document 02515: removed 10 unavailable source(s).
# Document 02515 has no available sources. Removing from map.
# Document 02549: removed 9 unavailable source(s).
# Document 02549 has no available sources. Removing from map.
# Document 02657: removed 6 unavailable source(s).
# Document 02674: removed 7 unavailable source(s).
# Document 02674 has no available sources. Removing from map.
# Document 02707: removed 3 unavailable source(s).
# Document 02707 has no available sources. Removing from map.
# Document 02715: removed 4 unavailable source(s).
# Document 02715 has no available sources. Removing from map.
# Document 02749: removed 11 unavailable source(s).
# Document 02766: removed 7 unavailable source(s).
# Document 02766 has no available sources. Removing from map.
# Document 02770: removed 4 unavailable source(s).
# Document 02770 has no available sources. Removing from map.
# Document 02773: removed 23 unavailable source(s).
# Document 02773 has no available sources. Removing from map.
# Document 02789: removed 16 unavailable source(s).
# Document 02824: removed 16 unavailable source(s).
# Document 02831: removed 7 unavailable source(s).
# Document 02831 has no available sources. Removing from map.
# Document 02842: removed 16 unavailable source(s).
# Document 02850: removed 22 unavailable source(s).
# Document 02864: removed 23 unavailable source(s).
# Document 02892: removed 3 unavailable source(s).
# Document 02895: removed 7 unavailable source(s).
# Document 02895 has no available sources. Removing from map.
# Document 02925: removed 2 unavailable source(s).
# Document 02925 has no available sources. Removing from map.
# Document 02956: removed 1 unavailable source(s).
# Document 02956 has no available sources. Removing from map.
# Document 03002: removed 4 unavailable source(s).
# Document 03002 has no available sources. Removing from map.
# Document 03030: removed 6 unavailable source(s).
# Document 03030 has no available sources. Removing from map.
# Document 03045: removed 4 unavailable source(s).
# Document 03061: removed 14 unavailable source(s).
# Document 03061 has no available sources. Removing from map.
# Document 03064: removed 20 unavailable source(s).
# Document 03064 has no available sources. Removing from map.
# Document 03100: removed 20 unavailable source(s).
# Document 03145: removed 7 unavailable source(s).
# Document 03145 has no available sources. Removing from map.
# Document 03152: removed 24 unavailable source(s).
# Document 03156: removed 4 unavailable source(s).
# Document 03156 has no available sources. Removing from map.
# Document 03189: removed 21 unavailable source(s).
# Document 03189 has no available sources. Removing from map.
# Document 03192: removed 4 unavailable source(s).
# Document 03202: removed 3 unavailable source(s).
# Document 03202 has no available sources. Removing from map.
# Document 03267: removed 5 unavailable source(s).
# Document 03267 has no available sources. Removing from map.
# Document 03313: removed 2 unavailable source(s).
# Document 03313 has no available sources. Removing from map.
# Document 03319: removed 7 unavailable source(s).
# Document 03319 has no available sources. Removing from map.
# Document 03347: removed 22 unavailable source(s).
# Document 03347 has no available sources. Removing from map.
# Document 03352: removed 2 unavailable source(s).
# Document 03352 has no available sources. Removing from map.
# Document 03387: removed 15 unavailable source(s).
# Document 03393: removed 13 unavailable source(s).
# Document 03393 has no available sources. Removing from map.
# Document 03412: removed 5 unavailable source(s).
# Document 03412 has no available sources. Removing from map.
# Document 03415: removed 6 unavailable source(s).
# Document 03416: removed 7 unavailable source(s).
# Document 03416 has no available sources. Removing from map.
# Document 03420: removed 6 unavailable source(s).
# Document 03420 has no available sources. Removing from map.
# Document 03436: removed 6 unavailable source(s).
# Document 03436 has no available sources. Removing from map.
# Document 03448: removed 5 unavailable source(s).
# Document 03448 has no available sources. Removing from map.
# Document 03464: removed 2 unavailable source(s).
# Document 03492: removed 4 unavailable source(s).
# Document 03496: removed 18 unavailable source(s).
# Document 03496 has no available sources. Removing from map.
# Document 03507: removed 20 unavailable source(s).
# Document 03510: removed 17 unavailable source(s).
# Document 03510 has no available sources. Removing from map.
# Document 03564: removed 12 unavailable source(s).
# Document 03568: removed 4 unavailable source(s).
# Document 03572: removed 18 unavailable source(s).
# Document 03572 has no available sources. Removing from map.
# Document 03603: removed 4 unavailable source(s).
# Document 03603 has no available sources. Removing from map.
# Document 03606: removed 5 unavailable source(s).
# Document 03610: removed 5 unavailable source(s).
# Document 03610 has no available sources. Removing from map.
# Document 03612: removed 1 unavailable source(s).
# Document 03614: removed 17 unavailable source(s).
# Document 03614 has no available sources. Removing from map.
# Document 03630: removed 4 unavailable source(s).
# Document 03630 has no available sources. Removing from map.
# Document 03643: removed 2 unavailable source(s).
# Document 03649: removed 3 unavailable source(s).
# Document 03649 has no available sources. Removing from map.
# Document 03651: removed 13 unavailable source(s).
# Document 03661: removed 10 unavailable source(s).
# Document 03661 has no available sources. Removing from map.
# Document 03669: removed 9 unavailable source(s).
# Document 03669 has no available sources. Removing from map.
# Document 03675: removed 8 unavailable source(s).
# Document 03675 has no available sources. Removing from map.
# Document 03711: removed 2 unavailable source(s).
# Document 03711 has no available sources. Removing from map.
# Document 03728: removed 3 unavailable source(s).
# Document 03728 has no available sources. Removing from map.
# Document 03730: removed 3 unavailable source(s).
# Document 03730 has no available sources. Removing from map.
# Document 03757: removed 25 unavailable source(s).
# Document 03800: removed 13 unavailable source(s).
# Document 03807: removed 8 unavailable source(s).
# Document 03807 has no available sources. Removing from map.
# Document 03820: removed 2 unavailable source(s).
# Document 03820 has no available sources. Removing from map.
# Document 03836: removed 46 unavailable source(s).
# Document 03840: removed 5 unavailable source(s).
# Document 03840 has no available sources. Removing from map.
# Document 03854: removed 7 unavailable source(s).
# Document 03924: removed 17 unavailable source(s).
# Document 03924 has no available sources. Removing from map.
# Document 03950: removed 2 unavailable source(s).
# Document 03950 has no available sources. Removing from map.
# Document 03967: removed 1 unavailable source(s).
# Document 03967 has no available sources. Removing from map.
# Document 03973: removed 7 unavailable source(s).
# Document 03973 has no available sources. Removing from map.
# Document 03986: removed 7 unavailable source(s).
# Document 03997: removed 3 unavailable source(s).
# Document 03997 has no available sources. Removing from map.
# Document 04021: removed 4 unavailable source(s).
# Document 04021 has no available sources. Removing from map.
# Document 04028: removed 9 unavailable source(s).
# Document 04028 has no available sources. Removing from map.
# Document 04040: removed 6 unavailable source(s).
# Document 04040 has no available sources. Removing from map.
# Document 04055: removed 2 unavailable source(s).
# Document 04055 has no available sources. Removing from map.
# Document 04064: removed 3 unavailable source(s).
# Document 04084: removed 3 unavailable source(s).
# Document 04084 has no available sources. Removing from map.
# Document 04086: removed 13 unavailable source(s).
# Document 04086 has no available sources. Removing from map.
# Document 04093: removed 4 unavailable source(s).
# Document 04106: removed 23 unavailable source(s).
# Document 04106 has no available sources. Removing from map.
# Document 04148: removed 3 unavailable source(s).
# Document 04148 has no available sources. Removing from map.
# Document 04159: removed 2 unavailable source(s).
# Document 04159 has no available sources. Removing from map.
# Document 04187: removed 2 unavailable source(s).
# Document 04187 has no available sources. Removing from map.
# Document 04219: removed 4 unavailable source(s).
# Document 04219 has no available sources. Removing from map.
# Document 04227: removed 32 unavailable source(s).
# Document 04227 has no available sources. Removing from map.
# Document 04237: removed 4 unavailable source(s).
# Document 04237 has no available sources. Removing from map.
# Document 04248: removed 2 unavailable source(s).
# Document 04248 has no available sources. Removing from map.
# Document 04262: removed 2 unavailable source(s).
# Document 04271: removed 2 unavailable source(s).
# Document 04271 has no available sources. Removing from map.
# Document 04282: removed 7 unavailable source(s).
# Document 04282 has no available sources. Removing from map.
# Document 04312: removed 3 unavailable source(s).
# Document 04312 has no available sources. Removing from map.
# Document 04318: removed 4 unavailable source(s).
# Document 04318 has no available sources. Removing from map.
# Document 04330: removed 2 unavailable source(s).
# Document 04330 has no available sources. Removing from map.
# Document 04336: removed 13 unavailable source(s).
# Document 04372: removed 5 unavailable source(s).
# Document 04372 has no available sources. Removing from map.
# Document 04382: removed 1 unavailable source(s).
# Document 04382 has no available sources. Removing from map.
# Document 04385: removed 23 unavailable source(s).
# Document 04404: removed 6 unavailable source(s).
# Document 04404 has no available sources. Removing from map.
# Document 04431: removed 5 unavailable source(s).
# Document 04431 has no available sources. Removing from map.
# Document 04432: removed 12 unavailable source(s).
# Document 04432 has no available sources. Removing from map.
# Document 04472: removed 20 unavailable source(s).
# Document 04472 has no available sources. Removing from map.
# Document 04474: removed 14 unavailable source(s).
# Document 04474 has no available sources. Removing from map.
# Document 04494: removed 11 unavailable source(s).
# Document 04516: removed 1 unavailable source(s).
# Document 04516 has no available sources. Removing from map.
# Document 04523: removed 26 unavailable source(s).
# Document 04529: removed 63 unavailable source(s).
# Document 04529 has no available sources. Removing from map.
# Document 04561: removed 16 unavailable source(s).
# Document 04561 has no available sources. Removing from map.
# Document 04569: removed 2 unavailable source(s).
# Document 04569 has no available sources. Removing from map.
# Document 04612: removed 27 unavailable source(s).
# Document 04612 has no available sources. Removing from map.
# Document 04614: removed 12 unavailable source(s).
# Document 04614 has no available sources. Removing from map.
# Document 04619: removed 4 unavailable source(s).
# Document 04619 has no available sources. Removing from map.
# Document 04622: removed 10 unavailable source(s).
# Document 04622 has no available sources. Removing from map.
# Document 04631: removed 89 unavailable source(s).
# Document 04645: removed 26 unavailable source(s).
# Document 04688: removed 4 unavailable source(s).
# Document 04697: removed 1 unavailable source(s).
# Document 04697 has no available sources. Removing from map.
# Document 04722: removed 9 unavailable source(s).
# Document 04722 has no available sources. Removing from map.
# Document 04729: removed 4 unavailable source(s).
# Document 04729 has no available sources. Removing from map.
# Document 04735: removed 11 unavailable source(s).
# Document 04747: removed 6 unavailable source(s).
# Document 04747 has no available sources. Removing from map.
# Document 04754: removed 4 unavailable source(s).
# Document 04754 has no available sources. Removing from map.
# Document 04776: removed 23 unavailable source(s).
# Document 04789: removed 7 unavailable source(s).
# Document 04789 has no available sources. Removing from map.
# Document 04800: removed 6 unavailable source(s).
# Document 04800 has no available sources. Removing from map.
# Document 04818: removed 3 unavailable source(s).
# Document 04818 has no available sources. Removing from map.
# Document 04858: removed 3 unavailable source(s).
# Document 04858 has no available sources. Removing from map.
# Document 04883: removed 13 unavailable source(s).
# Document 04883 has no available sources. Removing from map.
# Document 04959: removed 18 unavailable source(s).
# Document 04959 has no available sources. Removing from map.
# Document 04968: removed 4 unavailable source(s).
# Document 04968 has no available sources. Removing from map.
# Document 04969: removed 5 unavailable source(s).
# Document 04969 has no available sources. Removing from map.
# Document 04972: removed 13 unavailable source(s).
# Document 04973: removed 5 unavailable source(s).
# Document 04973 has no available sources. Removing from map.
# Document 04981: removed 7 unavailable source(s).
# Document 05005: removed 3 unavailable source(s).
# Document 05005 has no available sources. Removing from map.
# Document 05013: removed 5 unavailable source(s).
# Document 05013 has no available sources. Removing from map.
# Document 05020: removed 20 unavailable source(s).
# Document 05042: removed 11 unavailable source(s).
# Document 05042 has no available sources. Removing from map.
# Document 05074: removed 4 unavailable source(s).
# Document 05074 has no available sources. Removing from map.
# Document 05075: removed 2 unavailable source(s).
# Document 05075 has no available sources. Removing from map.
# Document 05079: removed 6 unavailable source(s).
# Document 05079 has no available sources. Removing from map.
# Document 05086: removed 5 unavailable source(s).
# Document 05086 has no available sources. Removing from map.
# Document 05087: removed 12 unavailable source(s).
# Document 05087 has no available sources. Removing from map.
# Document 05094: removed 4 unavailable source(s).
# Document 05094 has no available sources. Removing from map.
# Document 05097: removed 4 unavailable source(s).
# Document 05097 has no available sources. Removing from map.
# Document 05106: removed 2 unavailable source(s).
# Document 05106 has no available sources. Removing from map.
# Document 05123: removed 4 unavailable source(s).
# Document 05127: removed 4 unavailable source(s).
# Document 05129: removed 9 unavailable source(s).
# Document 05129 has no available sources. Removing from map.
# Document 05149: removed 1 unavailable source(s).
# Document 05149 has no available sources. Removing from map.
# Document 05180: removed 11 unavailable source(s).
# Document 05180 has no available sources. Removing from map.
# Document 05183: removed 4 unavailable source(s).
# Document 05183 has no available sources. Removing from map.
# Document 05204: removed 9 unavailable source(s).
# Document 05204 has no available sources. Removing from map.
# Document 05220: removed 10 unavailable source(s).
# Document 05220 has no available sources. Removing from map.
# Document 05221: removed 2 unavailable source(s).
# Document 05221 has no available sources. Removing from map.
# Document 05287: removed 2 unavailable source(s).
# Document 05287 has no available sources. Removing from map.
# Document 05313: removed 30 unavailable source(s).
# Document 05320: removed 6 unavailable source(s).
# Document 05320 has no available sources. Removing from map.
# Document 05326: removed 8 unavailable source(s).
# Document 05326 has no available sources. Removing from map.
# Document 05341: removed 5 unavailable source(s).
# Document 05341 has no available sources. Removing from map.
# Document 05342: removed 1 unavailable source(s).
# Document 05342 has no available sources. Removing from map.
# Document 05374: removed 2 unavailable source(s).
# Document 05374 has no available sources. Removing from map.
# Document 05388: removed 5 unavailable source(s).
# Document 05394: removed 8 unavailable source(s).
# Document 05394 has no available sources. Removing from map.
# Document 05429: removed 8 unavailable source(s).
# Document 05429 has no available sources. Removing from map.
# Document 05446: removed 18 unavailable source(s).
# Document 05446 has no available sources. Removing from map.
# Document 05453: removed 6 unavailable source(s).
# Document 05453 has no available sources. Removing from map.
# Document 05480: removed 16 unavailable source(s).
# Document 05483: removed 5 unavailable source(s).
# Document 05483 has no available sources. Removing from map.
# Document 05519: removed 20 unavailable source(s).
# Document 05519 has no available sources. Removing from map.
# Document 05521: removed 18 unavailable source(s).
# Document 05523: removed 20 unavailable source(s).
# Document 05523 has no available sources. Removing from map.
# Document 05527: removed 3 unavailable source(s).
# Document 05527 has no available sources. Removing from map.
# Document 05536: removed 12 unavailable source(s).
# Document 05536 has no available sources. Removing from map.
# Document 05554: removed 5 unavailable source(s).
# Document 05554 has no available sources. Removing from map.
# Document 05562: removed 6 unavailable source(s).
# Document 05562 has no available sources. Removing from map.
# Document 05567: removed 1 unavailable source(s).
# Document 05577: removed 4 unavailable source(s).
# Document 05589: removed 11 unavailable source(s).
# Document 05589 has no available sources. Removing from map.
# Document 05619: removed 10 unavailable source(s).
# Document 05619 has no available sources. Removing from map.
# Document 05643: removed 25 unavailable source(s).
# Document 05663: removed 9 unavailable source(s).
# Document 05675: removed 6 unavailable source(s).
# Document 05675 has no available sources. Removing from map.
# Document 05705: removed 5 unavailable source(s).
# Document 05744: removed 1 unavailable source(s).
# Document 05744 has no available sources. Removing from map.
# Document 05789: removed 13 unavailable source(s).
# Document 05797: removed 9 unavailable source(s).
# Document 05797 has no available sources. Removing from map.
# Document 05846: removed 57 unavailable source(s).
# Document 05846 has no available sources. Removing from map.
# Document 05847: removed 3 unavailable source(s).
# Document 05847 has no available sources. Removing from map.
# Document 05859: removed 8 unavailable source(s).
# Document 05859 has no available sources. Removing from map.
# Document 05880: removed 8 unavailable source(s).
# Document 05880 has no available sources. Removing from map.
# Document 05899: removed 3 unavailable source(s).
# Document 05899 has no available sources. Removing from map.
# Document 05907: removed 24 unavailable source(s).
# Document 05907 has no available sources. Removing from map.
# Document 05909: removed 3 unavailable source(s).
# Document 05909 has no available sources. Removing from map.
# Document 05915: removed 2 unavailable source(s).
# Document 05915 has no available sources. Removing from map.
# Document 05921: removed 4 unavailable source(s).
# Document 05921 has no available sources. Removing from map.
# Document 05957: removed 4 unavailable source(s).
# Document 05957 has no available sources. Removing from map.
# Document 05958: removed 2 unavailable source(s).
# Document 05958 has no available sources. Removing from map.
# Document 05973: removed 10 unavailable source(s).
# Document 05973 has no available sources. Removing from map.
# Document 05983: removed 17 unavailable source(s).
# Document 05983 has no available sources. Removing from map.
# Document 05998: removed 8 unavailable source(s).
# Document 05998 has no available sources. Removing from map.
# Document 06031: removed 8 unavailable source(s).
# Document 06031 has no available sources. Removing from map.
# Document 06080: removed 7 unavailable source(s).
# Document 06080 has no available sources. Removing from map.
# Document 06084: removed 11 unavailable source(s).
# Document 06089: removed 20 unavailable source(s).
# Document 06096: removed 19 unavailable source(s).
# Document 06101: removed 7 unavailable source(s).
# Document 06101 has no available sources. Removing from map.
# Document 06106: removed 6 unavailable source(s).
# Document 06106 has no available sources. Removing from map.
# Document 06110: removed 6 unavailable source(s).
# Document 06110 has no available sources. Removing from map.
# Document 06129: removed 9 unavailable source(s).
# Document 06129 has no available sources. Removing from map.
# Document 06141: removed 5 unavailable source(s).
# Document 06141 has no available sources. Removing from map.
# Document 06164: removed 1 unavailable source(s).
# Document 06167: removed 5 unavailable source(s).
# Document 06178: removed 24 unavailable source(s).
# Document 06194: removed 2 unavailable source(s).
# Document 06194 has no available sources. Removing from map.
# Document 06228: removed 1 unavailable source(s).
# Document 06228 has no available sources. Removing from map.
# Document 06251: removed 5 unavailable source(s).
# Document 06251 has no available sources. Removing from map.
# Document 06252: removed 1 unavailable source(s).
# Document 06261: removed 2 unavailable source(s).
# Document 06261 has no available sources. Removing from map.
# Document 06262: removed 7 unavailable source(s).
# Document 06262 has no available sources. Removing from map.
# Document 06275: removed 13 unavailable source(s).
# Document 06278: removed 1 unavailable source(s).
# Document 06278 has no available sources. Removing from map.
# Document 06306: removed 2 unavailable source(s).
# Document 06306 has no available sources. Removing from map.
# Document 06323: removed 10 unavailable source(s).
# Document 06337: removed 5 unavailable source(s).
# Document 06342: removed 3 unavailable source(s).
# Document 06342 has no available sources. Removing from map.
# Document 06348: removed 39 unavailable source(s).
# Document 06348 has no available sources. Removing from map.
# Document 06404: removed 2 unavailable source(s).
# Document 06404 has no available sources. Removing from map.
# Document 06437: removed 11 unavailable source(s).
# Document 06437 has no available sources. Removing from map.
# Document 06475: removed 8 unavailable source(s).
# Document 06475 has no available sources. Removing from map.
# Document 06497: removed 3 unavailable source(s).
# Document 06497 has no available sources. Removing from map.
# Document 06504: removed 3 unavailable source(s).
# Document 06513: removed 3 unavailable source(s).
# Document 06513 has no available sources. Removing from map.
# Document 06569: removed 1 unavailable source(s).
# Document 06588: removed 6 unavailable source(s).
# Document 06588 has no available sources. Removing from map.
# Document 06596: removed 24 unavailable source(s).
# Document 06596 has no available sources. Removing from map.
# Document 06647: removed 7 unavailable source(s).
# Document 06647 has no available sources. Removing from map.
# Document 06653: removed 7 unavailable source(s).
# Document 06653 has no available sources. Removing from map.
# Document 06670: removed 12 unavailable source(s).
# Document 06701: removed 12 unavailable source(s).
# Document 06701 has no available sources. Removing from map.
# Document 06726: removed 1 unavailable source(s).
# Document 06739: removed 2 unavailable source(s).
# Document 06739 has no available sources. Removing from map.
# Document 06780: removed 4 unavailable source(s).
# Document 06785: removed 1 unavailable source(s).
# Document 06785 has no available sources. Removing from map.
# Document 06821: removed 9 unavailable source(s).
# Document 06821 has no available sources. Removing from map.
# Document 06822: removed 3 unavailable source(s).
# Document 06822 has no available sources. Removing from map.
# Document 06845: removed 2 unavailable source(s).
# Document 06845 has no available sources. Removing from map.
# Document 06849: removed 3 unavailable source(s).
# Document 06849 has no available sources. Removing from map.
# Document 06860: removed 34 unavailable source(s).
# Document 06872: removed 21 unavailable source(s).
# Document 06872 has no available sources. Removing from map.
# Document 06889: removed 5 unavailable source(s).
# Document 06889 has no available sources. Removing from map.
# Document 06897: removed 2 unavailable source(s).
# Document 06904: removed 4 unavailable source(s).
# Document 06904 has no available sources. Removing from map.
# Document 06925: removed 11 unavailable source(s).
# Document 06925 has no available sources. Removing from map.
# Document 06939: removed 13 unavailable source(s).
# Document 06939 has no available sources. Removing from map.
# Document 06941: removed 9 unavailable source(s).
# Document 06948: removed 7 unavailable source(s).
# Document 06948 has no available sources. Removing from map.
# Document 06953: removed 26 unavailable source(s).
# Document 06953 has no available sources. Removing from map.
# Document 06972: removed 1 unavailable source(s).
# Document 06972 has no available sources. Removing from map.
# Document 06978: removed 16 unavailable source(s).
# Document 07002: removed 4 unavailable source(s).
# Document 07002 has no available sources. Removing from map.
# Document 07007: removed 3 unavailable source(s).
# Document 07007 has no available sources. Removing from map.
# Document 07024: removed 8 unavailable source(s).
# Document 07024 has no available sources. Removing from map.
# Document 07051: removed 18 unavailable source(s).
# Document 07080: removed 4 unavailable source(s).
# Document 07080 has no available sources. Removing from map.
# Document 07088: removed 16 unavailable source(s).
# Document 07088 has no available sources. Removing from map.
# Document 07102: removed 17 unavailable source(s).
# Document 07102 has no available sources. Removing from map.
# Document 07106: removed 18 unavailable source(s).
# Document 07106 has no available sources. Removing from map.
# Document 07145: removed 5 unavailable source(s).
# Document 07151: removed 15 unavailable source(s).
# Document 07194: removed 30 unavailable source(s).
# Document 07194 has no available sources. Removing from map.
# Document 07199: removed 5 unavailable source(s).
# Document 07199 has no available sources. Removing from map.
# Document 07206: removed 2 unavailable source(s).
# Document 07206 has no available sources. Removing from map.
# Final plagiarism map size: 137
# Total unavailable sources removed: 4071

# %%
# list the first five documents in the final plagiarism map as a sanity check
print("\nFirst 5 entries in the final plagiarism map:")
for i, (doc_id, sources) in enumerate(list(plagiarism_map.items())[:10]):
    print(f"  Document {doc_id}: plagiarized from {sources}")
# Out:
# First 5 entries in the final plagiarism map:
#   Document 00014: plagiarized from ['00852', '04678']
#   Document 00109: plagiarized from ['06229', '05899', '05270', '04973', '06229', '05270', '04973', '04973', '04973', '04973', '05270', '04973']
#   Document 00171: plagiarized from ['04040']
#   Document 00264: plagiarized from ['01942']
#   Document 00357: plagiarized from ['03480', '03480']
#   Document 00445: plagiarized from ['01472', '01472']
#   Document 00468: plagiarized from ['03711']
#   Document 00476: plagiarized from ['03604']
#   Document 00511: plagiarized from ['01160', '01160', '01160', '01160']
#   Document 00514: plagiarized from ['03649', '03649', '03649']

# %%
# size of map (unique keys and unique source IDs across all values)
unique_docs = set(plagiarism_map.keys())
unique_sources = set(src for sources in plagiarism_map.values() for src in sources)
print(f"\nPlagiarism cases with at least one available source: {len(unique_docs)}")
print(f"Plagiarism sources whose .txt is present in corpus: {len(unique_sources)}")
# Out:
# Plagiarism cases with at least one available source: 137
# Plagiarism sources whose .txt is present in corpus: 155

# %% [markdown]
# ## 5. Pre-processing
#
# ### 5.1 Load suspicious document texts

# %%
def clean_text(text):
    """Clean and normalise text by lowercasing and collapsing whitespace."""
    text = text.strip().lower()
    text = re.sub(r"\s+", " ", text)
    text = re.sub(r'[^a-z0-9\s]', '', text) # remove punctuation and special characters
    return text

def load_single_doc(path) -> str:
    text = path.read_text(encoding="utf-8", errors="ignore")
    text = clean_text(text)
    return text

def load_corpus(paths) -> dict:
    """Load a list of .txt Paths → {stem: normalised_text}."""
    corpus = {}
    for p in paths:
        text = load_single_doc(p)
        corpus[p.stem] = text
    return corpus

corpus = sorted(CORPUS_DIR.glob("source-document*.txt"))

# uncomment this to load only the documents that either a. have available plagiarism sources, or b. are sources themselves (i.e., they appear in the values of the plagiarism map AND in the corpus)
# selected_docs = sorted(unique_docs.union(unique_sources))
# corpus = [CORPUS_DIR / f"source-document{doc_id}.txt" for doc_id in selected_docs]

if (debug):
    corpus = documents

print(f"Suspicious docs loaded : {len(corpus)}")
# print(f"Suspicious docs loaded : {len(txt_paths)}")
# Out:
# Suspicious docs loaded : 902

# %%
# remove the "source-document" prefix and ".txt" suffix to get just the ID for each document in the corpus
if (not debug):
    corpus_ids = [p.stem.replace("source-document", "") for p in corpus]
    print(f"First 5 corpus IDs: {corpus_ids[:5]}")

    # check that the corpus ids match the entries in the ground truth
    # if any of them are missing, report the offending ID and expected file path
    gt_ids = set(gt["doc_name"])
    missing_from_corpus = sorted(gt_ids - set(corpus_ids))
    if missing_from_corpus:
        print(f"\nThe following GT document IDs are missing from the corpus:")
        for doc_id in missing_from_corpus:
            print(f"  {doc_id} -> expected file: {CORPUS_DIR / f'source-document{doc_id}.txt'}")

    # now check the other way around: if there are any corpus IDs that are not in the GT, report them as well
    missing_from_gt = sorted(set(corpus_ids) - gt_ids)
    if missing_from_gt:
        print(f"\nThe following corpus document IDs are missing from the GT:")
        for doc_id in missing_from_gt:
            print(f"  {doc_id} -> file: {CORPUS_DIR / f'source-document{doc_id}.txt'}")
# Out:
# First 5 corpus IDs: ['00014', '00044', '00052', '00060', '00072']
#
# The following corpus document IDs are missing from the GT:
#   06862 -> file: /Users/vitto/Desktop/SP26/DA/project_1/15_Suspicious_Passages/31.Suspicious_Passages/corpus/source-document06862.txt

# %% [markdown]
# ### 5.2 Shingling

# %%
K_SHINGLE = 9   # character k-gram size; 9 is typical for long documents

# def build_shingles(text: str, k: int = K_SHINGLE) -> frozenset:
#     """Return the set of all k-character substrings of *text*."""
#     return frozenset(text[i:i+k] for i in range(len(text) - k + 1))

# note: we hash the shingles to 32-bit integers to save memory, since the original shingles can be very large (especially for long documents and large k)
def build_shingles(doc_text: str, k: int):
   # Convert document text into a set of substrings (shingles)
    shingles = []
    for i in range(len(doc_text) - k):
        # shingles.append(doc_text[i:i+k])
        # shingle = doc_text[i:i+k]
        # shingle = np.int32(hash(doc_text[i:i+k]))  # hash the shingle to a 32-bit integer
        shingle = hash(doc_text[i:i+k]) & 0xFFFFFFFF  # hash the shingle to a 32-bit integer
        shingles.append(shingle)
    return set(shingles)

shingles = []
# for name, text in corpus.items():
#     shingles.append(build_shingles(text, K_SHINGLE))

# we load documents one by one and build shingles on the fly to save memory, instead of loading the entire corpus at once

if (debug):
    for doc_text in corpus:
        text = clean_text(doc_text)
        # assert text is not empty after cleaning
        # else, print a warning with the offending document id
        # assert text, f"Warning: document text is empty after cleaning. Original text: {doc_text[:100]}..."
        shingles.append(build_shingles(text, K_SHINGLE))
else:
    for path in corpus:
        text = load_single_doc(path)
        shingles.append(build_shingles(text, K_SHINGLE))
    del text  # free memory (might not be necessary but just in case)

# shingles = {name: build_shingles(text, K_SHINGLE) for name, text in corpus.items()}
print(f"Number of shingle sets: {len(shingles)}")
# Out:
# Number of shingle sets: 902

# %%
# print the first 5 shingles of the first document as a sanity check
if (not debug):
    print(f"First 5 shingles of the first document ({corpus[0].stem}):")
    print(list(shingles[0])[:5])
# Out:
# First 5 shingles of the first document (source-document00014):
# [543162368, 2376073216, 3945267202, 3237478403, 385351683]

# %% [markdown]
# ### 5.3 Build Global Vocabulary & One-Hot Encoding

# %%
def build_vocab(shingle_sets: list):
    # Convert list of shingle sets into a global shingle->index map.
    full_set = {item for set_ in shingle_sets for item in set_}
    vocab = {}
    for i, shingle in enumerate(full_set):
        vocab[shingle] = i
    return vocab

def shingle_index_list(shingle_set: set, vocab: dict):
    # Return vocab indices for all shingles present in one document.
    return [vocab[s] for s in shingle_set if s in vocab]

def one_hot(shingles: set, vocab: dict):
    #Convert a set of shingles → numeric vector
    # assert shingle set is not empty
    # assert shingles, "Error: empty shingle set provided to one_hot function."
    if not shingles:
        print(f"Warning: empty shingle set provided to one_hot function. Returning all-zero vector.")
    vec = np.zeros(len(vocab))
    for shingle in shingles:
        idx = vocab[shingle]
        vec[idx] = 1
    # if resulting vector is all zeros, print a warning with the offending shingle set
    # assert np.sum(vec) > 0, f"Error: one-hot vector is all zeros for shingle set: {shingles}"
    if np.sum(vec) == 0:
        print(f"Warning: one-hot vector is all zeros for shingle set: {shingles}")
    # if np.sum(vec) == 0:
        # print(f"Warning: one-hot vector is all zeros for shingle set: {shingles}")
    return vec

# %%
# build vocab
vocab = build_vocab(shingles)
print(f"Vocab size: {len(vocab):,}")

# one-hot encode our shingles
# Goal: Convert a set of shingles into a numeric vector (one-hot encoding)
if (debug):
    # if in debug mode, we can afford to build a dense one-hot matrix for simplicity and easier debugging
    print("Building dense one-hot matrix (debug mode)...")
    shingles_1hot = []
    for shingle_set in shingles:
        shingles_1hot.append(one_hot(shingle_set, vocab))
    # stack into single numpy array
    shingles_1hot = np.stack(shingles_1hot)
    shingles_1hot.shape

else:
    # when using the full datatset, we need to build a sparse one-hot matrix to save memory
    print("Building sparse one-hot matrix (PAN dataset)...")
    # Build sparse one-hot matrix directly in CSR format.
    rows = []
    cols = []

    for row_idx, shingle_set in enumerate(shingles):
        idxs = shingle_index_list(shingle_set, vocab)
        rows.extend([row_idx] * len(idxs))
        cols.extend(idxs)

    data = np.ones(len(rows), dtype=np.uint8)
    shingles_1hot = csr_matrix(
        (data, (np.array(rows, dtype=np.int32), np.array(cols, dtype=np.int32))),
        shape=(len(shingles), len(vocab)),
        dtype=np.uint8,
    )

    print(f"Sparse one-hot shape: {shingles_1hot.shape}")
    print(f"Non-zeros: {shingles_1hot.nnz:,}")
    print(f"Density: {shingles_1hot.nnz / (shingles_1hot.shape[0] * shingles_1hot.shape[1]):.8f}")
# Out:
# Vocab size: 24,577,427
# Building sparse one-hot matrix (PAN dataset)...
# Sparse one-hot shape: (902, 24577427)
# Non-zeros: 87,774,986
# Density: 0.00395939

# %%
# all_shingles: set = set()
# for shingle_set in shingles.values():
#     all_shingles.update(shingle_set)

# vocab = {shingle: idx for idx, shingle in enumerate(sorted(all_shingles))}
# VOCAB_SIZE = len(vocab)
# print(f"Vocabulary size: {VOCAB_SIZE:,}")

# def one_hot_vector(shingles: frozenset, vocab: dict) -> np.ndarray:
#     vec = np.zeros(len(vocab), dtype=np.uint8)
#     for s in shingles:
#         if s in vocab:
#             vec[vocab[s]] = 1
#     return vec

# doc_names = sorted(shingles.keys())   # e.g. ["suspicious-document00001", ...]
# print(f"Building one-hot matrix for {len(doc_names)} documents …")
# one_hot_matrix = np.stack([one_hot_vector(shingles[n], vocab) for n in doc_names])
# print(f"One-hot matrix shape: {one_hot_matrix.shape}")

# %%
# print the first 10 elements of the vocab to see what the shingles look like
print("First 10 shingles in vocab:")
for i, shingle in enumerate(vocab.keys()):
    if i >= 10:
        break
    print(f"{i}: '{shingle}'")
# Out:
# First 10 shingles in vocab:
# 0: '3154116608'
# 1: '939524098'
# 2: '536870914'
# 3: '1476395011'
# 4: '2214592518'
# 5: '67108874'
# 6: '1677721611'
# 7: '1677721613'
# 8: '2080374797'
# 9: '2013265937'

# %%
# display the first 5 rows of the one-hot matrix as a sanity check
print("First 5 rows of the sparse one-hot matrix:")
# print(shingles_1hot[:5].toarray())
shingles_1hot[:5]
# Out:
# First 5 rows of the sparse one-hot matrix:
# <Compressed Sparse Row sparse matrix of dtype 'uint8'
# 	with 1279013 stored elements and shape (5, 24577427)>

# %%
# assert all rows have at least one shingle present (sum > 0)
# row_sums = shingles_1hot.sum(axis=1).A1  # sum across columns, convert to 1D array
row_sums = shingles_1hot.sum(axis=1)  # sum across columns
row_sums.sort()
row_sums
# Out:
# matrix([[ 252712],
#         [ 157079],
#         [ 169680],
#         [ 173707],
#         [ 525835],
#         [  19500],
#         [ 144721],
#         [ 518731],
#         [  19161],
#         [   3338],
#         [  25654],
#         [  15437],
#         [  16880],
#         [ 743311],
#         [   2740],
#         [   8221],
#         [   9990],
#         [   2738],
#         [ 136089],
#         [  13430],
#         [  10058],
#         [ 115108],
#         [   3870],
#         [  13326],
#         [ 134546],
#         [   8889],
#         [  25979],
#         [  22632],
#         [ 491669],
#         [  26974],
#         [ 106325],
#         [   3255],
#         [   3103],
#         [  20816],
#         [  11432],
#         [ 289890],
#         [   9744],
#         [ 285182],
#         [ 156626],
#         [  14081],
#         [   8879],
#         [   6747],
#         [  22672],
#         [   2466],
#         [ 145277],
#         [   2743],
#         [   2974],
#         [  31173],
#         [  16611],
#         [   2891],
#         [  15714],
#         [ 196517],
#         [  23422],
#         [   2199],
#         [ 181554],
#         [ 211173],
#         [  36747],
#         [   3192],
#         [  78792],
#         [  18949],
#         [  13522],
#         [  92830],
#         [ 300197],
#         [  28694],
#         [ 133109],
#         [ 258546],
#         [  16081],
#         [ 229377],
#         [  63826],
#         [   3545],
#         [ 118128],
#         [  79915],
#         [ 622012],
#         [  81901],
#         [  72817],
#         [  22381],
#         [   3498],
#         [   2358],
#         [  12423],
#         [ 317077],
#         [   9587],
#         [ 174232],
#         [   3356],
#         [   6387],
#         [   6853],
#         [ 173090],
#         [  31051],
#         [ 305211],
#         [  28313],
#         [  58430],
#         [  31187],
#         [ 199208],
#         [  13652],
#         [ 203782],
#         [  26067],
#         [ 370110],
#         [   2848],
#         [ 163885],
#         [  12702],
#         [  12405],
#         [  12615],
#         [  26509],
#         [   6837],
#         [  16778],
#         [  20086],
#         [  23930],
#         [ 674621],
#         [ 143011],
#         [  98655],
#         [   3404],
#         [  13838],
#         [ 110843],
#         [  24546],
#         [   7326],
#         [ 172564],
#         [  69308],
#         [ 210728],
#         [   3205],
#         [   3330],
#         [  10386],
#         [ 137081],
#         [ 189045],
#         [  97283],
#         [  13124],
#         [ 135517],
#         [  50073],
#         [ 136676],
#         [ 232707],
#         [ 194056],
#         [   6651],
#         [ 232169],
#         [  71204],
#         [ 107334],
#         [ 225072],
#         [ 195384],
#         [  19343],
#         [ 135533],
#         [   5536],
#         [   3710],
#         [   3045],
#         [  13370],
#         [  30220],
#         [   6966],
#         [  61325],
#         [ 113158],
#         [  84861],
#         [  25015],
#         [  28878],
#         [ 173986],
#         [ 146911],
#         [ 121596],
#         [  24395],
#         [  24983],
#         [  19144],
#         [ 305774],
#         [ 116510],
#         [  28538],
#         [   9828],
#         [   6236],
#         [  20932],
#         [  24139],
#         [ 214374],
#         [ 206877],
#         [  19524],
#         [ 438343],
#         [ 629315],
#         [   6637],
#         [ 151323],
#         [ 111627],
#         [   9040],
#         [ 233495],
#         [  22386],
#         [ 135323],
#         [  26396],
#         [ 295638],
#         [  88863],
#         [  14321],
#         [ 288538],
#         [  27664],
#         [   3242],
#         [  31596],
#         [  12653],
#         [ 234955],
#         [  10089],
#         [   3126],
#         [  65229],
#         [  99648],
#         [  13296],
#         [ 200473],
#         [   5994],
#         [  11443],
#         [ 230288],
#         [ 326152],
#         [   5746],
#         [ 349951],
#         [  25221],
#         [  24525],
#         [   2707],
#         [  13956],
#         [ 166969],
#         [  29955],
#         [  41336],
#         [ 151918],
#         [   9106],
#         [   2877],
#         [  10834],
#         [ 114033],
#         [  31822],
#         [  12472],
#         [  18793],
#         [  13864],
#         [   2769],
#         [   2903],
#         [ 141109],
#         [ 215311],
#         [   6437],
#         [  12135],
#         [ 306709],
#         [  85517],
#         [ 386394],
#         [   2742],
#         [ 174357],
#         [ 136852],
#         [   3337],
#         [   2860],
#         [   9993],
#         [  33065],
#         [   3493],
#         [ 204529],
#         [  24117],
#         [   6184],
#         [  58863],
#         [   2448],
#         [ 186993],
#         [ 473311],
#         [  12697],
#         [ 185550],
#         [  18998],
#         [  10149],
#         [  26392],
#         [   2670],
#         [  60346],
#         [  12694],
#         [ 333872],
#         [   3451],
#         [   6415],
#         [   3123],
#         [   3085],
#         [ 243722],
#         [   6189],
#         [ 719203],
#         [   6216],
#         [  12565],
#         [ 153824],
#         [  10941],
#         [ 203882],
#         [  13881],
#         [   3152],
#         [ 343154],
#         [  19446],
#         [   3717],
#         [  38178],
#         [  13566],
#         [ 122555],
#         [  26537],
#         [ 172376],
#         [ 136235],
#         [   3282],
#         [ 131789],
#         [  23783],
#         [  32904],
#         [ 499483],
#         [   5202],
#         [  19715],
#         [ 120817],
#         [ 375402],
#         [ 406934],
#         [  22769],
#         [ 177354],
#         [  10442],
#         [ 569175],
#         [ 299257],
#         [  16646],
#         [   2745],
#         [   4517],
#         [   8548],
#         [  18833],
#         [  26178],
#         [  27252],
#         [ 446746],
#         [ 127624],
#         [ 239296],
#         [ 152475],
#         [  87697],
#         [  22136],
#         [   2473],
#         [  14726],
#         [  13127],
#         [  43502],
#         [ 275877],
#         [ 216088],
#         [   6305],
#         [ 413173],
#         [  78629],
#         [   3258],
#         [ 212720],
#         [  54342],
#         [  30633],
#         [   2929],
#         [  27635],
#         [ 173753],
#         [  24807],
#         [  24554],
#         [  30213],
#         [  30011],
#         [   2960],
#         [ 394078],
#         [  21988],
#         [ 164516],
#         [ 239887],
#         [  16444],
#         [  93778],
#         [  66546],
#         [  26238],
#         [ 532811],
#         [  10228],
#         [   9816],
#         [ 260219],
#         [  19599],
#         [ 109074],
#         [  88237],
#         [ 411107],
#         [   5845],
#         [ 109653],
#         [   3424],
#         [ 173848],
#         [   8064],
#         [ 192015],
#         [ 188434],
#         [  23071],
#         [   3282],
#         [ 313203],
#         [  13485],
#         [   6624],
#         [  16070],
#         [ 281977],
#         [   5483],
#         [  30527],
#         [ 896062],
#         [   6243],
#         [   3268],
#         [   3818],
#         [  12991],
#         [   6394],
#         [ 140963],
#         [ 217165],
#         [  31922],
#         [   7662],
#         [ 186385],
#         [  13253],
#         [ 192523],
#         [  15000],
#         [   6315],
#         [ 151593],
#         [ 179021],
#         [ 236646],
#         [  91800],
#         [ 331338],
#         [   8420],
#         [ 423706],
#         [1183564],
#         [ 271127],
#         [ 242536],
#         [   6565],
#         [   3252],
#         [   9903],
#         [ 273065],
#         [  18592],
#         [   2299],
#         [  26666],
#         [   3224],
#         [  16909],
#         [ 433430],
#         [  10434],
#         [ 203119],
#         [ 305619],
#         [ 277748],
#         [ 135107],
#         [ 288899],
#         [ 133372],
#         [  51977],
#         [ 112554],
#         [  15391],
#         [    892],
#         [  31127],
#         [  10240],
#         [   3545],
#         [  25305],
#         [ 129063],
#         [  13587],
#         [ 493964],
#         [  21494],
#         [  70999],
#         [  17128],
#         [   6029],
#         [  21193],
#         [   3345],
#         [ 157371],
#         [  68155],
#         [ 107102],
#         [  24175],
#         [  19163],
#         [   3403],
#         [   6619],
#         [  16491],
#         [   3420],
#         [ 218565],
#         [ 187648],
#         [  16957],
#         [   6859],
#         [  10089],
#         [  30667],
#         [   9653],
#         [ 404555],
#         [   3252],
#         [   3134],
#         [  13263],
#         [  10059],
#         [ 563818],
#         [   2852],
#         [   3705],
#         [ 142460],
#         [   6842],
#         [  29084],
#         [   5374],
#         [ 219230],
#         [ 127522],
#         [   5091],
#         [   1422],
#         [  27811],
#         [ 100378],
#         [ 440555],
#         [ 165147],
#         [  56970],
#         [ 212059],
#         [ 111010],
#         [  20877],
#         [ 226255],
#         [  29342],
#         [ 336509],
#         [  31189],
#         [  31664],
#         [  28705],
#         [   3233],
#         [ 195249],
#         [  12973],
#         [  20761],
#         [   6543],
#         [  12757],
#         [  10952],
#         [  31488],
#         [  37215],
#         [ 107704],
#         [  10239],
#         [ 534272],
#         [ 127874],
#         [  28118],
#         [   3140],
#         [  45344],
#         [ 323986],
#         [ 206927],
#         [ 164640],
#         [  15994],
#         [  10787],
#         [ 184606],
#         [  15994],
#         [ 100150],
#         [  11692],
#         [  23022],
#         [  21909],
#         [  32084],
#         [  16287],
#         [ 150241],
#         [ 158565],
#         [   9666],
#         [   5705],
#         [  16522],
#         [ 306445],
#         [   5433],
#         [   3289],
#         [   3061],
#         [  24881],
#         [  14363],
#         [   9583],
#         [  15432],
#         [   6503],
#         [ 485820],
#         [  30238],
#         [   2921],
#         [  13050],
#         [  16222],
#         [ 164748],
#         [  29478],
#         [ 328506],
#         [  22670],
#         [  88014],
#         [ 184870],
#         [  60142],
#         [ 168864],
#         [  14747],
#         [  22335],
#         [  85537],
#         [   9997],
#         [   3410],
#         [   4990],
#         [  15364],
#         [  13748],
#         [  25432],
#         [   5611],
#         [  75715],
#         [ 286155],
#         [  25590],
#         [ 291911],
#         [  28772],
#         [   9226],
#         [  10001],
#         [   3337],
#         [   3688],
#         [ 221312],
#         [  25956],
#         [ 181162],
#         [ 494201],
#         [  65792],
#         [ 106233],
#         [   6285],
#         [   9826],
#         [  12493],
#         [  30700],
#         [  21971],
#         [  83818],
#         [ 368606],
#         [   6412],
#         [ 148823],
#         [  21465],
#         [   4147],
#         [ 337503],
#         [ 407147],
#         [  70615],
#         [  12252],
#         [  70879],
#         [   6835],
#         [ 185548],
#         [ 145334],
#         [  11262],
#         [   4039],
#         [ 164151],
#         [ 109501],
#         [   3272],
#         [  18164],
#         [  21388],
#         [  25282],
#         [  14142],
#         [   3045],
#         [   3271],
#         [ 212465],
#         [ 146901],
#         [  16487],
#         [   2941],
#         [ 228949],
#         [ 284010],
#         [  10129],
#         [  11762],
#         [   3209],
#         [  19222],
#         [  19859],
#         [   6515],
#         [  27768],
#         [ 316419],
#         [ 230130],
#         [ 312105],
#         [   2851],
#         [ 163592],
#         [ 130477],
#         [ 206979],
#         [   4782],
#         [ 117084],
#         [  19933],
#         [  26173],
#         [ 558976],
#         [   6376],
#         [  14404],
#         [  40461],
#         [   6321],
#         [  28127],
#         [  97691],
#         [ 237059],
#         [  25643],
#         [  11120],
#         [   3308],
#         [ 211562],
#         [  98429],
#         [  21969],
#         [ 296520],
#         [   2057],
#         [ 187175],
#         [  11807],
#         [ 146903],
#         [ 171836],
#         [  71513],
#         [  16332],
#         [  11733],
#         [ 398697],
#         [ 232080],
#         [  16624],
#         [  31258],
#         [   9294],
#         [  19452],
#         [  15776],
#         [  31638],
#         [  29483],
#         [  28374],
#         [  11665],
#         [  22570],
#         [  16192],
#         [ 181727],
#         [   3458],
#         [  29703],
#         [  24413],
#         [ 108757],
#         [ 199076],
#         [  75094],
#         [ 361157],
#         [ 106061],
#         [  31425],
#         [   7141],
#         [  13790],
#         [  15361],
#         [ 485036],
#         [ 110977],
#         [ 177421],
#         [   8866],
#         [ 123572],
#         [ 118427],
#         [   9307],
#         [ 232549],
#         [  15884],
#         [  20352],
#         [  31735],
#         [   3020],
#         [   6430],
#         [  60930],
#         [  13069],
#         [   9124],
#         [   8454],
#         [ 211816],
#         [  14983],
#         [   6540],
#         [  12703],
#         [ 138173],
#         [  65222],
#         [   3211],
#         [  29744],
#         [   6712],
#         [ 302301],
#         [ 278163],
#         [   3279],
#         [   5111],
#         [ 204900],
#         [   2913],
#         [ 149174],
#         [  13080],
#         [   3042],
#         [ 115349],
#         [   3698],
#         [  18801],
#         [  57642],
#         [  24720],
#         [ 322706],
#         [  15919],
#         [   6847],
#         [  18751],
#         [   9811],
#         [  19912],
#         [   3441],
#         [ 266508],
#         [  45470],
#         [  25489],
#         [ 254102],
#         [   3108],
#         [ 204030],
#         [ 140907],
#         [  28838],
#         [  10276],
#         [   3245],
#         [   4835],
#         [  18081],
#         [  13062],
#         [  25388],
#         [  12440],
#         [ 221911],
#         [ 438867],
#         [  82388],
#         [  13988],
#         [ 230330],
#         [   2939],
#         [  14106],
#         [   6443],
#         [  23964],
#         [  13682],
#         [  22736],
#         [    790],
#         [ 373633],
#         [  29421],
#         [   6951],
#         [  10003],
#         [   7176],
#         [  16574],
#         [   6661],
#         [   3518],
#         [ 188747],
#         [ 134726],
#         [  57071],
#         [   6402],
#         [   3402],
#         [ 163303],
#         [  13174],
#         [  10101],
#         [  28472],
#         [  22320],
#         [   3161],
#         [  23409],
#         [  13076],
#         [   3297],
#         [  27042],
#         [  18132],
#         [  25536],
#         [   1723],
#         [  63515],
#         [  20034],
#         [ 178030],
#         [ 391043],
#         [  18277],
#         [  12836],
#         [ 867692],
#         [ 272227],
#         [ 338311],
#         [  98073],
#         [  15462],
#         [   3041],
#         [   2773],
#         [ 422336],
#         [ 567216],
#         [  14383],
#         [ 427645],
#         [   2833],
#         [  18531],
#         [  34755],
#         [ 214129],
#         [ 172242],
#         [  24432],
#         [ 276634],
#         [  25517],
#         [  29097],
#         [ 138183],
#         [ 322545],
#         [  52771],
#         [ 144314],
#         [ 103295],
#         [ 137382],
#         [   2752],
#         [ 457753],
#         [ 210151],
#         [  16639],
#         [  16755],
#         [ 216339],
#         [   3108],
#         [ 154383],
#         [   1859],
#         [  12543],
#         [  26428],
#         [  29368],
#         [   6107],
#         [ 204088],
#         [  11513],
#         [   2673],
#         [   2608],
#         [  89307],
#         [  33238],
#         [  64208],
#         [   8312],
#         [  19048],
#         [  18790],
#         [  26629],
#         [   9714],
#         [  29221],
#         [  25906],
#         [  25153],
#         [   2721],
#         [  28164],
#         [  16266],
#         [  19889],
#         [   6998],
#         [   2252],
#         [  15818],
#         [  98271],
#         [ 362419],
#         [  15062],
#         [  31928],
#         [  11434],
#         [   5620],
#         [  14023],
#         [  25081],
#         [   9214],
#         [  18504],
#         [  17317],
#         [   5998],
#         [  19488],
#         [ 208690],
#         [ 303336],
#         [   2955],
#         [   5816],
#         [   6399],
#         [   5732],
#         [  24765],
#         [  19282],
#         [  27069],
#         [   2836],
#         [  50792],
#         [  48180],
#         [  26122],
#         [ 223911],
#         [ 300596],
#         [ 189202],
#         [ 306458],
#         [  67145],
#         [   9888],
#         [  24890],
#         [  87869],
#         [  31657],
#         [   5247],
#         [   3348],
#         [  12977],
#         [  15050],
#         [ 319112],
#         [  28316],
#         [  88343],
#         [  11194],
#         [ 217573],
#         [  90274],
#         [  12654],
#         [ 306997],
#         [   3395],
#         [ 189541],
#         [ 250086],
#         [  25535],
#         [ 275219],
#         [  12760],
#         [  12802],
#         [ 168502],
#         [ 146125],
#         [   7953],
#         [ 276558],
#         [ 159610],
#         [  26627],
#         [   3563],
#         [  21327],
#         [  22490],
#         [ 113134],
#         [   8404],
#         [  18221],
#         [   5243],
#         [ 467805],
#         [   9172],
#         [   3189],
#         [ 285140],
#         [  12865],
#         [ 140410],
#         [ 240539],
#         [ 220946],
#         [ 257285],
#         [ 155221],
#         [  83896],
#         [   9449],
#         [  27191],
#         [ 417867],
#         [ 457262],
#         [   6232],
#         [ 155744],
#         [  27773],
#         [  44704],
#         [  18168],
#         [  12509],
#         [ 229858],
#         [ 188348],
#         [   3365],
#         [  18019],
#         [ 201320],
#         [ 740059],
#         [  18049],
#         [ 173111],
#         [ 255281],
#         [   9911]], dtype=uint64)

# %%
# how many rows sum to 0
num_zero_rows = np.sum(row_sums == 0)
print(f"Number of rows with sum 0: {num_zero_rows}")
# Out:
# Number of rows with sum 0: 0

# %%
# assert np.all(row_sums > 0), "All documents should have at least one shingle present (no empty rows)"
if np.any(row_sums == 0):
    print("Warning: Some documents have no shingles present (empty rows in one-hot matrix).")

# %% [markdown]
# ## 6. MinHash Signatures

# %%
def minhash_arr(vocab: dict, resolution: int):
    # Goal: Create a MinHash matrix with random permutations
    # Each row represents a different hash function (permutation of indices)
    length = len(vocab.keys())
    arr = np.zeros((resolution, length))
    for i in range(resolution):
        permutation = np.random.permutation(len(vocab)) + 1
        arr[i, :] = permutation.copy()
    return arr.astype(int)

def get_signature(minhash, vector):
    # Goal: Compute the MinHash signature for a given one-hot vector
    # This produces a compact representation for similarity comparison
    # get index locations of every 1 value in vector
    idx = np.nonzero(vector)[0].tolist()
    # use index locations to pull only +ve positions in minhash
    shingles = minhash[:, idx]
    # find minimum value in each hash vector
    # if shingles is empty (i.e., the document has no shingles), return a signature of all zeros
    if shingles.shape[1] == 0:
        print("Warning: No shingles found for this document. Returning zero signature.")
        return np.zeros(minhash.shape[0], dtype=int)
    signature = np.min(shingles, axis=1) # horizontally
    return signature

# %%
n_hashes = 100
# n_hashes = 200
arr = minhash_arr(vocab, n_hashes)
# Goal: Generate 100 MinHash functions (random permutations) based on the vocabulary
signatures = []

for vector in shingles_1hot:
    signatures.append(get_signature(arr, vector))
# Goal: Compute a compact MinHash signature for each one-hot encoded sentence

# merge signatures into single array
signatures = np.stack(signatures)
# Goal: Combine all signatures into one matrix (each row = one sentence signature)
signatures.shape
# Out:
# (902, 100)

# %%
signatures[0]
# Out:
# array([ 4572431, 13541400, 12144308, 19876645, 12868426, 20096510,
#          374303, 12609085,  3939925, 21435512,  7305669,  6968585,
#        19873574,  3004602,  2186570, 20495031,  8813254, 11450686,
#          311723,  5181829,  2344338, 21163398,  5234666,  6181948,
#        15170860,  1409446,  6304696,  8751137, 14039595,  4864951,
#        10359425,  2646835,  8695466, 15431283,  4715105,  6885448,
#         9261424, 19622174, 12887115,  5440225,  5858020, 23197132,
#        18733388, 19745905, 18783479,   322603, 18763762,  5557868,
#         6534987, 18052725,  9651001, 14939668, 16144070, 17258039,
#        12830384,  3034586, 10456907, 23243927,   466445,  7535000,
#         6555224, 18773066, 24473286,  8251727, 23485834,  4529479,
#        18741710, 17090617, 23464987, 22405217, 12991934, 10466781,
#          251099, 14063753,  2931773,  8977060, 15639497,  2577340,
#        17858332, 24113680,  1249914, 17503041, 20476708,  9867450,
#         5138155, 19259202,  6511516, 13900480, 20680596, 23224145,
#        22390108, 22594368,  3913153,  9550300, 22201848,  1094549,
#        11831823,  3992823, 19293401,   380468])

# %% [markdown]
# ## 7. Locality-Sensitive Hashing (LSH)

# %%
class LSH:
    buckets = []
    counter = 0

    def __init__(self, b):
        # Goal: Initialize the LSH structure with b bands
        # Each band will store buckets of similar signature parts
        
        self.b = b
        for i in range(b):
            self.buckets.append({})

    def make_subvecs(self, signature):
        # Goal: Split a MinHash signature into b equal-sized subvectors (bands)
        # Each band will be used to group similar signatures
        
        l = len(signature)
        assert l % self.b == 0
        r = int(l / self.b)
        
        # break signature into subvectors
        subvecs = []
        for i in range(0, l, r):
            subvecs.append(signature[i:i+r])
        
        return np.stack(subvecs)
    
    def add_hash(self, signature):
        # Goal: Hash each band of the signature into buckets
        # Similar signatures will fall into the same bucket in at least one band
        
        subvecs = self.make_subvecs(signature).astype(str)
        
        for i, subvec in enumerate(subvecs):
            subvec = ','.join(subvec)
            
            if subvec not in self.buckets[i].keys():
                self.buckets[i][subvec] = []
            
            self.buckets[i][subvec].append(self.counter)
        
        self.counter += 1
        # Goal: Assign a unique ID to each signature added

    def check_candidates(self):
        # Goal: Find candidate pairs of similar items
        # Items that share a bucket in any band are considered potential matches
        
        candidates = []
        
        for bucket_band in self.buckets:
            keys = bucket_band.keys()
            
            for bucket in keys:
                hits = bucket_band[bucket]
                
                if len(hits) > 1:
                    candidates.extend(combinations(hits, 2))
        
        return set(candidates)
        # Goal: Return unique pairs of candidate similar items

# %%
b = 20
# Goal: Define the number of bands for LSH

lsh = LSH(b)
# Goal: Initialize the LSH model with b bands (each band will group similar signatures)

for signature in signatures:
    lsh.add_hash(signature)
# Goal: Insert each MinHash signature into LSH buckets to group similar items together

# %%
# print the number of hashes, bands, and rows
print(f"Number of hashes (signature length): {n_hashes}")
print(f"Number of bands: {b}")
rows = n_hashes // b
print(f"Number of rows per band: {rows}")
cand_prob = 1-(1-(0.8**rows))**b # 0.8 = the real Jaccard sim between the two docs
print(f"Prob that the signatures agree in all rows of at least one band, and thus become candidate pairs: {cand_prob:.4f}")
# Out:
# Number of hashes (signature length): 100
# Number of bands: 20
# Number of rows per band: 5
# Prob that the signatures agree in all rows of at least one band, and thus become candidate pairs: 0.9996

# %%
candidate_pairs = lsh.check_candidates()
# Goal: Retrieve all candidate pairs of sentences that were placed in the same bucket
# in at least one band → these are likely similar pairs (filtered by LSH)

len(candidate_pairs)
# Goal: Count how many candidate pairs were found (reduces comparisons vs all possible pairs)

# total possible number of pairs = n choose 2 = n*(n-1)/2
n = len(corpus)
# n = len(txt_paths)
total_pairs = n * (n - 1) // 2
print(f"Total possible pairs: {total_pairs:,}")
print(f"Candidate pairs found: {len(candidate_pairs):,}")

# TODO: too many candidate pairs are being generated, adjust the parameters?
# Out:
# Total possible pairs: 406,351
# Candidate pairs found: 406,351

# %%
list(candidate_pairs)[:5]
# Out:
# [(1, 751), (436, 679), (35, 335), (785, 833), (298, 745)]

# %%
def jaccard_similarity(set1, set2):
    intersection = len(set1.intersection(set2))
    union = len(set1.union(set2))
    if union == 0:
        return 0.0
    return intersection / union

# %%
# check the real Jaccard similarity of the first 5 candidate pairs as a sanity check

# sort candidate pairs by their jaccard similarity in descending order and print the top 5 pairs with their similarity score
sort_list = candidate_pairs

# grab only the first 1000 candidate pairs to speed up the sorting for this sanity check
# uncomment this if you want to sort all candidate pairs, but be aware it might take a while if there are many pairs
sort_list = list(candidate_pairs)[:1000]


sorted_candidates = sorted(sort_list, key=lambda pair: jaccard_similarity(shingles[pair[0]], shingles[pair[1]]), reverse=True)
print("Top 5 candidate pairs sorted by Jaccard similarity:")
for pair in sorted_candidates[:5]:
    sim = jaccard_similarity(shingles[pair[0]], shingles[pair[1]])
    print(f"Pair {pair}: Jaccard similarity = {sim:.4f}")
# Out:
# Top 5 candidate pairs sorted by Jaccard similarity:
# Pair (4, 87): Jaccard similarity = 0.1274
# Pair (382, 874): Jaccard similarity = 0.1206
# Pair (382, 711): Jaccard similarity = 0.1134
# Pair (579, 745): Jaccard similarity = 0.1095
# Pair (327, 874): Jaccard similarity = 0.1052

# %% [markdown]
# As we can see, not only are the number of candidate pairs very large (in fact, it is equal to the *total* possible number of pairs, n(n-1)), but the Jaccard similarity values of the top candidate pairs are also very low.

# %%
# grab the most similar pair, find their document IDs, and print which shingles they have in common as a sanity check
if (not debug):
    most_similar_pair = sorted_candidates[0]
    doc_id_1 = corpus[most_similar_pair[0]].stem
    doc_id_2 = corpus[most_similar_pair[1]].stem
    common_shingles = shingles[most_similar_pair[0]].intersection(shingles[most_similar_pair[1]])
    print(f"\nMost similar pair: {most_similar_pair} (docs {doc_id_1} and {doc_id_2})")
    print(f"Number of common shingles: {len(common_shingles)}")
    print(f"Example common shingles: {list(common_shingles)[:5]}")

    # check in the plagiarism map if these two documents plagiarise from each other as a sanity check
    if doc_id_1 in plagiarism_map and doc_id_2 in plagiarism_map[doc_id_1]:
        print(f"Document {doc_id_1} plagiarises from {doc_id_2} according to the plagiarism map.")
    elif doc_id_2 in plagiarism_map and doc_id_1 in plagiarism_map[doc_id_2]:
        print(f"Document {doc_id_2} plagiarises from {doc_id_1} according to the plagiarism map.")
    else:
        print(f"No plagiarism relationship found between {doc_id_1} and {doc_id_2} in the plagiarism map.")
# Out:
# Most similar pair: (4, 87) (docs source-document00072 and source-document00647)
# Number of common shingles: 93938
# Example common shingles: [2376073216, 3687579649, 3707240450, 385351683, 2701393923]
# No plagiarism relationship found between source-document00072 and source-document00647 in the plagiarism map.

# %%
# list the doc names of the first 5 candidate pairs as a sanity check
if (not debug):
    print("\nFirst 5 candidate pairs (by document name):")
    for i, (idx1, idx2) in enumerate(list(candidate_pairs)[:10]):
        doc1 = corpus[idx1].stem  # e.g. "source-document02721"
        doc1_id = doc1.replace("source-document", "")
        doc2 = corpus[idx2].stem
        doc2_id = doc2.replace("source-document", "")
        # print pair of doc ids and if theyre a known plagiarism case in the GT
        # pair: doc1_id (1|0) - doc2_id (1|0)
        gt1 = gt.loc[gt["doc_name"] == doc1_id, "plagiarism"].values[0]
        gt2 = gt.loc[gt["doc_name"] == doc2_id, "plagiarism"].values[0]
        print(f"  Pair {i+1}: {doc1_id} ({'Plagiarised' if gt1 == 1 else 'Clean'}) - {doc2_id} ({'Plagiarised' if gt2 == 1 else 'Clean'})")
# Out:
# First 5 candidate pairs (by document name):
#   Pair 1: 00044 (Plagiarised) - 06070 (Clean)
#   Pair 2: 03670 (Plagiarised) - 05480 (Plagiarised)
#   Pair 3: 00317 (Clean) - 02864 (Plagiarised)
#   Pair 4: 06287 (Clean) - 06734 (Clean)
#   Pair 5: 02511 (Clean) - 05998 (Plagiarised)
#   Pair 6: 02064 (Plagiarised) - 04601 (Clean)
#   Pair 7: 05212 (Clean) - 07206 (Plagiarised)
#   Pair 8: 00447 (Clean) - 04176 (Clean)
#   Pair 9: 01099 (Clean) - 02316 (Plagiarised)
#   Pair 10: 04841 (Plagiarised) - 07172 (Clean)

# %% [markdown]
# # 8. Verification

# %%
THRESHOLD = 0.5  # threshold for considering a pair as truly similar
r = int(n_hashes / b)
print(f"Using threshold: {THRESHOLD:.4f} (for b={b}, r={r}, n_hashes={n_hashes})")

true_positives = []
false_positives = []

total_trials = 5000 # check only the first m candidate pairs for faster testing (TODO: remove?)
i = 0
for idx1, idx2 in list(candidate_pairs):
    if idx1 == idx2:
        # print(f"Skipping self-pair: ({idx1}, {idx2})")
        continue  # skip self-pairs
    if i >= total_trials:
        break
    doc1 = shingles[idx1]
    doc2 = shingles[idx2]
    sim = jaccard_similarity(doc1, doc2)
    
    if sim >= THRESHOLD:  # threshold for considering a pair as truly similar
        true_positives.append((idx1, idx2, sim))
    else:
        false_positives.append((idx1, idx2, sim))

    i += 1

print(f"True positives (similar pairs above threshold): {len(true_positives)}")
print(f"False positives (pairs below threshold): {len(false_positives)}")
# Out:
# Using threshold: 0.5000 (theoretical for b=20, r=5, n_hashes=100)
# True positives (similar pairs above threshold): 0
# False positives (pairs below threshold): 5000

# %%
# verification for the 20 newsgroups dataset. the results should be in line with those reported in the reference implementation (linked above)
# this chunk of code was copied directly from the reference implementation to make comparisons easier
if (debug):
    num_docs = len(corpus)
    total_possible = num_docs * (num_docs - 1) // 2

    print("\n" + "=" * 60)
    print("FINAL RESULTS")
    print("=" * 60)
    print(f"Dataset: {num_docs} documents from 20 Newsgroups")
    print(f"Total possible comparisons: {total_possible:,}")
    print(f"LSH candidate pairs: {len(candidate_pairs):,}")
    print(f"Speedup: {total_possible / len(candidate_pairs):.1f}x")
    print(f"\nPlagiarism Detection (Jaccard ≥ {THRESHOLD}):")
    print(f"True Positives: {len(true_positives)}")
    print(f"False Positives: {len(false_positives)}")

    # Show an example if we found plagiarism
    if true_positives:
        print("\n" + "=" * 60)
        print("EXAMPLE OF DETECTED PLAGIARISM")
        print("=" * 60)
        doc1, doc2, sim = true_positives[0]
        print(f"Documents {doc1} and {doc2} are {sim*100:.1f}% similar\n")
        print(f"Document {doc1} (first 300 chars):")
        print(documents[doc1][:300] + "...\n")
        print(f"Document {doc2} (first 300 chars):")
        print(documents[doc2][:300] + "...")

# %%
# out of all the TP pairs, list the top 10 with the highest Jaccard similarity as a sanity check
true_positives.sort(key=lambda x: x[2], reverse=True)  # sort by similarity
print("\nTop 10 true positives (by Jaccard similarity):")
for i, (idx1, idx2, sim) in enumerate(true_positives[:10]):
    if idx1 == idx2:
        continue  # skip self-pairs
    if (debug):
        doc1 = idx1
        doc2 = idx2
    else:
        doc1 = corpus[idx1].stem
        doc2 = corpus[idx2].stem
    print(f"  Pair {i+1}: {doc1} - {doc2} | Jaccard similarity: {sim:.4f}")
# Out:
# Top 10 true positives (by Jaccard similarity):

# %%
# for the top 5 candidates with the highest Jaccard similarity, load their original text and print which shingles they had in common to see if the similarity is due to a few shared phrases or if they are really very similar across the board
if (not debug):
    print("\nTop 5 candidate pairs with shared shingles:")
    for idx1, idx2 in list(candidate_pairs)[:5]:
        doc_name1 = corpus[idx1].stem.replace("source-document", "")
        doc_name2 = corpus[idx2].stem.replace("source-document", "")
        sim = jaccard_similarity(shingles[idx1], shingles[idx2])
        print(f"Pair ({doc_name1}, {doc_name2}) - Jaccard similarity: {sim:.4f}")

        # load original text for both documents
        text1 = load_single_doc(CORPUS_DIR / f"source-document{doc_name1}.txt")
        text2 = load_single_doc(CORPUS_DIR / f"source-document{doc_name2}.txt")

        # build shingles again to find the common ones
        shingles1 = build_shingles(text1, K_SHINGLE)
        shingles2 = build_shingles(text2, K_SHINGLE)

        common_shingles = shingles1.intersection(shingles2)
        print(f"  Number of shared shingles: {len(common_shingles)}")
        print(f"  Example shared shingles: {list(common_shingles)[:5]}")

        # check if either document is in the GT as plagiarised
        gt_plag1 = gt.loc[gt["doc_name"] == doc_name1, "plagiarism"].values
        gt_plag2 = gt.loc[gt["doc_name"] == doc_name2, "plagiarism"].values
        if len(gt_plag1) > 0 and gt_plag1[0] == 1:
            print(f"  {doc_name1} is marked as plagiarised in GT")
            # list the docs it plagiarised (check the plagiarism map)
            if doc_name1 in plagiarism_map:
                sources = plagiarism_map[doc_name1]
                print(f"  {doc_name1} plagiarised from: {sources}")
        if len(gt_plag2) > 0 and gt_plag2[0] == 1:
            print(f"  {doc_name2} is marked as plagiarised in GT")
            if doc_name2 in plagiarism_map:
                sources = plagiarism_map[doc_name2]
                print(f"  {doc_name2} plagiarised from: {sources}")
# Out:
# Top 5 candidate pairs with shared shingles:
# Pair (00044, 06070) - Jaccard similarity: 0.0278
#   Number of shared shingles: 19582
#   Example shared shingles: [4109893632, 2250276865, 553779201, 1800699907, 3505848323]
#   00044 is marked as plagiarised in GT
# Pair (03670, 05480) - Jaccard similarity: 0.0094
#   Number of shared shingles: 1256
#   Example shared shingles: [906715136, 3589799948, 3421839379, 837550100, 1003995155]
#   03670 is marked as plagiarised in GT
#   03670 plagiarised from: ['02363', '02363']
#   05480 is marked as plagiarised in GT
#   05480 plagiarised from: ['00787']
# Pair (00317, 02864) - Jaccard similarity: 0.0641
#   Number of shared shingles: 27953
#   Example shared shingles: [553779201, 3707240450, 1113587715, 3687579649, 2701393923]
#   02864 is marked as plagiarised in GT
#   02864 plagiarised from: ['00852', '00803', '00803', '00852', '00803', '00803', '00803', '00803', '00803', '00803', '00852', '00858', '00803', '00803', '00852']
# Pair (06287, 06734) - Jaccard similarity: 0.0001
#   Number of shared shingles: 28
#   Example shared shingles: [599076611, 1115954052, 3662576774, 3372194831, 1627373602]
# Pair (02511, 05998) - Jaccard similarity: 0.0355
#   Number of shared shingles: 13090
#   Example shared shingles: [2134212609, 2701393923, 1457422341, 1881341962, 1488257035]
#   05998 is marked as plagiarised in GT
